# %% [markdown]
# Total params: 190,770
#
# Training Accuracy: 92.01%
#
# Validation Accuracy: 83.80%
#
# Test Accuracy: 81.4%
#
# Quantization Accuracy: 79.44% (79.435%)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import shutil
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report
from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Conv2D
from tensorflow.keras.optimizers import Adam

# %%
BATCH_SIZE = 128
# You may need to lower this depending upon your GPU

TARGET_SIZE = (80, 80)
# This model uses 80x80 images

# %%
# These were created as part of our data preparation notebook
filtered_train_storage_ds = "C:/colab/data/birds/cached/filtered/train"
filtered_valid_storage_ds = "C:/colab/data/birds/cached/filtered/valid"
filtered_test_storage_ds = "C:/colab/data/birds/cached/filtered/test"

# %%
# Generator
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    brightness_range=[0.75,1.15],
    rotation_range=30,
    channel_shift_range=10,
    width_shift_range=1.0,
    height_shift_range=1.0,
    shear_range=0.02,
    horizontal_flip=True,
    fill_mode='reflect',
)

# Many folks are against validation augmentation but I use it as the changes
# here are mostly minimal and gives more variation. The test generator is pure.
validation_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    brightness_range=[0.75,1.15],
    rotation_range=30,
    channel_shift_range=10,
    fill_mode='reflect',
    validation_split=0.2,
    horizontal_flip=True,
)


test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
train_images = train_generator.flow_from_directory(
    directory=filtered_train_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed=42,
    shuffle=True,
)

val_images = validation_generator.flow_from_directory(
    directory=filtered_valid_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed=42,
    shuffle=True,
)

test_images = test_generator.flow_from_directory(
    directory=filtered_test_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 42596 images belonging to 411 classes.
# Found 10554 images belonging to 411 classes.
# Found 13292 images belonging to 411 classes.

# %%
# Visualize the images
def visualize_generator(generator, samples = 5):
    batch_images, labels = next(generator)
    plt.figure(figsize=(10,5))
    for i in range(samples):
        plt.subplot(1, samples, i+1)
        plt.imshow(batch_images[i] / 255.0)
        plt.axis('off')
    plt.show()
    batch_images, labels = next(generator)
    plt.figure(figsize=(10,5))
    for i in range(samples):
        plt.subplot(1, samples, i+1)
        plt.imshow(batch_images[i+5] / 255.0)
        plt.axis('off')
    plt.show()
    batch_images, labels = next(generator)
    plt.figure(figsize=(10,5))
    for i in range(samples):
        plt.subplot(1, samples, i+1)
        plt.imshow(batch_images[i+10] / 255.0)
        plt.axis('off')
    plt.show()

print("Train images:")
visualize_generator(train_images)

print("Validation images:")
visualize_generator(val_images)

print("Test images:")
visualize_generator(test_images)
# Out:
# Train images:
# Validation images:
# Test images:

# %%
# absolute-cosine regularization
# https://www.amazon.science/publications/quantization-aware-training-with-absolute-cosine-regularization-for-automatic-speech-recognition
class ACosR(tf.keras.regularizers.Regularizer):
    def __init__(self, weight=1.0):
        self.weight = weight

    def __call__(self, weights):
        # Calculate the absolute cosine similarity
        cos_similarity = tf.reduce_mean(tf.abs(tf.reduce_sum(weights * tf.roll(weights, shift=1, axis=-1), axis=-1)))

        # Apply the regularization term to the loss
        regularization_loss = self.weight * cos_similarity

        return regularization_loss

    def get_config(self):
        return {'weight': float(self.weight)}

# %%
# Load the pretrained model
pretrained_model = tf.keras.applications.EfficientNetB0(input_shape=(80, 80, 3), include_top=False, weights='imagenet')
pretrained_model.trainable = False
selected_layer_index = 87
pretrained_model.layers[2]._name = 'normalization'

# Enable ACosR
for i in range(0, len(pretrained_model.layers)):
    layer = pretrained_model.layers[i]
    if isinstance(layer, keras.layers.Conv2D) or isinstance(layer, keras.layers.DepthwiseConv2D):
        pretrained_model.layers[i].kernel_regularizer = ACosR(weight = 0.005)

relu6 = keras.layers.ReLU(max_value=6, name="ReLU6")
for i in range(0, len(pretrained_model.layers)):
    if hasattr(pretrained_model.layers[i], "activation"):
        if "swish" in str(pretrained_model.layers[i].activation):
            pretrained_model.layers[i].activation = relu6

selected_layer_output = pretrained_model.layers[selected_layer_index].output
x = selected_layer_output
x = Conv2D(240, 1, groups=2, trainable=False, name="conv_s1", padding='valid', kernel_regularizer = ACosR(weight = 0.005))(x)
x = tf.keras.layers.BatchNormalization(trainable = False, name='tbd-b1')(x)
x = tf.keras.layers.Activation(relu6)(x)

x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = Dense(180, trainable = False, kernel_regularizer = ACosR(weight = 0.005), name="dense_s_1", activation=relu6)(x)
x = Dense(50, trainable = False, kernel_regularizer = ACosR(weight = 0.005), name="dense_2", activation=relu6)(x)
outputs = Dense(411, kernel_regularizer = ACosR(weight = 0.005), trainable = False, activation=tf.keras.activations.softmax, name="dense_output")(x)
model = Model(inputs=pretrained_model.input, outputs=outputs)
model.load_weights('C:/colab/data/birds/saves/80x80_411_full_relu6_post_decimation/saved_model')
model.summary()
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x0000022F1F186410> and <keras.layers.core.dense.Dense object at 0x0000022F1F185A50>).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 80, 80, 3)    0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 80, 80, 3)    7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 80, 80, 3)    0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 81, 81, 3)    0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 40, 40, 32)   864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 40, 40, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 40, 40, 32)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 40, 40, 32)  288         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 40, 40, 32)  128         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 40, 40, 32)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 40, 40, 32)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 40, 40, 16)   512         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 40, 40, 16)  64          ['block1a_project_conv[0][0]']
#  lization)
#
#  block2a_expand_conv (Conv2D)   (None, 40, 40, 96)   1536        ['block1a_project_bn[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 40, 40, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 40, 40, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 41, 41, 96)  0           ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 20, 20, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 20, 20, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 20, 20, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 20, 20, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 20, 20, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 20, 20, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 20, 20, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 20, 20, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 20, 20, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 20, 20, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 20, 20, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 20, 20, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 20, 20, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 20, 20, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 20, 20, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 20, 20, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 20, 20, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 20, 20, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 20, 20, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 20, 20, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 23, 23, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 10, 10, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 10, 10, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 10, 10, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 10, 10, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 10, 10, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 10, 10, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 10, 10, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 10, 10, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 10, 10, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 10, 10, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 10, 10, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 10, 10, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 10, 10, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 10, 10, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 10, 10, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 10, 10, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 10, 10, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 10, 10, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 10, 10, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 10, 10, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 11, 11, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 5, 5, 240)   2160        ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 5, 5, 240)   960         ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 5, 5, 240)   0           ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 5, 5, 240)    0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  conv_s1 (Conv2D)               (None, 5, 5, 240)    29040       ['block4a_se_excite[0][0]']
#
#  tbd-b1 (BatchNormalization)    (None, 5, 5, 240)    960         ['conv_s1[0][0]']
#
#  activation (Activation)        (None, 5, 5, 240)    0           ['tbd-b1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 240)         0           ['activation[0][0]']
#  alAveragePooling2D)
#
#  dense_s_1 (Dense)              (None, 180)          43380       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 50)           9050        ['dense_s_1[0][0]']
#
#  dense_output (Dense)           (None, 411)          20961       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 190,770
# Trainable params: 0
# Non-trainable params: 190,770
# __________________________________________________________________________________________________

# %%
# All layers are locked but running an epoch for demonstration purposes
model.compile(
    optimizer=Adam(1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    train_images,
    steps_per_epoch=len(train_images),
    validation_data=val_images,
    validation_steps=len(val_images),
    epochs=1,
)
# Out:
# 333/333 [==============================] - 78s 227ms/step - loss: 0.2984 - accuracy: 0.9201 - val_loss: 0.6722 - val_accuracy: 0.8380

# %%
# Now let's evaluate the test images against this checkpoint
results = model.evaluate(test_images, verbose=1)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# 104/104 [==============================] - 9s 90ms/step - loss: 0.8034 - accuracy: 0.8144
#     Test Loss: 0.80342
# Test Accuracy: 81.44%

# %%
# Let's now run predictions against the test images and show the output
# for a random subset as a grid
pred = model.predict(test_images)
pred = np.argmax(pred, axis=1)

# Map the label
labels = (test_images.class_indices)
labels = dict((v, k) for k, v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')

# Display 25 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_images.filepaths), 25)
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(25, 25), subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_images.filepaths[random_index[i]]))
    true_label = labels[test_images.classes[random_index[i]]]
    predicted_label = pred[random_index[i]]
    if true_label == predicted_label:
        color = "green"
    else:
        color = "red"
    ax.set_title(f"True: {true_label}\nPredicted: {predicted_label}", color=color)

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Classification report
y_test = [labels[idx] for idx in test_images.classes]
print(classification_report(y_test, pred))
# Out:
#                                precision    recall  f1-score   support
#
#               ABBOTTS BABBLER       0.66      0.76      0.70        33
#                 ABBOTTS BOOBY       0.55      0.47      0.51        36
#    ABYSSINIAN GROUND HORNBILL       0.84      0.86      0.85        36
#        AFRICAN EMERALD CUCKOO       0.66      0.68      0.67        31
#             AFRICAN FIREFINCH       0.92      0.81      0.86        27
#        AFRICAN OYSTER CATCHER       0.90      0.87      0.89        31
#         AFRICAN PIED HORNBILL       0.80      0.65      0.72        37
#                     ALBATROSS       0.55      0.42      0.48        26
#                ALBERTS TOWHEE       0.79      0.72      0.75        32
#          ALEXANDRINE PARAKEET       0.93      0.85      0.89        33
#                 ALPINE CHOUGH       0.88      0.85      0.86        33
#         ALTAMIRA YELLOWTHROAT       0.93      0.90      0.92        30
#               AMERICAN AVOCET       0.97      0.94      0.96        36
#              AMERICAN BITTERN       0.81      0.76      0.79        34
#                 AMERICAN COOT       0.89      0.75      0.81        32
#               AMERICAN DIPPER       0.74      0.82      0.78        39
#            AMERICAN GOLDFINCH       0.95      0.74      0.83        27
#              AMERICAN KESTREL       0.90      0.84      0.87        31
#                AMERICAN PIPIT       0.79      0.75      0.77        36
#             AMERICAN REDSTART       0.96      0.79      0.86        28
#                AMERICAN ROBIN       0.91      0.72      0.81        29
#               AMERICAN WIGEON       0.81      0.78      0.79        37
#             AMETHYST WOODSTAR       0.84      0.81      0.82        26
#                ANDEAN LAPWING       0.90      0.66      0.76        29
#                    FAIRY TERN       0.73      0.70      0.72        27
#              FAN TAILED WIDOW       0.83      0.67      0.74        30
#                 FIERY MINIVET       0.86      0.80      0.83        30
#         FIRE TAILLED MYZORNIS       0.94      1.00      0.97        30
#               FLAME BOWERBIRD       0.97      0.91      0.94        32
#                 FLAME TANAGER       0.88      0.80      0.84        35
#                FOREST WAGTAIL       0.87      0.79      0.83        34
#                       FRIGATE       0.76      0.78      0.77        32
#             FRILL BACK PIGEON       0.75      0.79      0.77        42
#                 GAMBELS QUAIL       0.85      0.94      0.89        31
#            GANG GANG COCKATOO       0.96      0.93      0.95        28
#               GILA WOODPECKER       0.86      1.00      0.93        31
#                GILDED FLICKER       0.53      0.29      0.37        28
#                  GO AWAY BIRD       0.69      0.69      0.69        26
#             GOLDEN BOWER BIRD       0.70      0.82      0.75        28
#           GOLDEN CHLOROPHONIA       0.92      0.81      0.86        27
#               GOLDEN PARAKEET       0.87      0.87      0.87        30
#                  GOLDEN PIPIT       0.88      0.91      0.89        32
#                GOULDIAN FINCH       1.00      0.94      0.97        31
#                      GRANDALA       0.89      0.83      0.86        30
#                  GRAY CATBIRD       0.79      0.87      0.83        31
#                 GRAY KINGBIRD       0.92      0.70      0.79        33
#                GRAY PARTRIDGE       0.77      0.72      0.74        32
#                   GREAT ARGUS       0.44      0.84      0.58        38
#                 GREAT JACAMAR       0.87      1.00      0.93        33
#                GREAT KISKADEE       0.94      0.88      0.91        34
#                   GREAT POTOO       0.80      0.43      0.56        28
#                 GREAT TINAMOU       0.59      0.48      0.53        33
#                  GREAT XENOPS       0.87      0.43      0.58        30
#                 GREATER PEWEE       0.88      0.48      0.62        31
#           GREATOR SAGE GROUSE       0.67      0.86      0.75        37
#               GREEN BROADBILL       0.90      0.93      0.91        28
#                     GREEN JAY       0.90      0.87      0.89        31
#                  GREEN MAGPIE       0.92      0.94      0.93        35
#             GREEN WINGED DOVE       1.00      0.74      0.85        31
#        GREY HEADED CHACHALACA       0.65      0.82      0.73        40
#                   GREY PLOVER       0.67      0.94      0.78        32
#             GROVED BILLED ANI       0.48      0.94      0.64        31
#                 GUINEA TURACO       0.80      0.62      0.70        32
#                 GURNEYS PITTA       0.86      0.97      0.91        32
#                      HAMERKOP       0.85      0.67      0.75        33
#                HARLEQUIN DUCK       0.96      0.80      0.87        30
#               HARLEQUIN QUAIL       0.62      0.59      0.60        27
#                      HAWFINCH       0.96      0.82      0.89        33
#                  HELMET VANGA       0.89      0.97      0.93        32
#               HEPATIC TANAGER       0.92      0.75      0.83        32
#            HIMALAYAN BLUETAIL       0.94      0.97      0.95        30
#               HIMALAYAN MONAL       0.97      1.00      0.98        30
#                       HOATZIN       0.63      0.84      0.72        31
#              HOODED MERGANSER       0.83      0.74      0.78        27
#                       HOOPOES       0.88      0.90      0.89        31
#                   HORNED GUAN       0.83      0.65      0.73        31
#                   HORNED LARK       1.00      0.86      0.92        35
#                 HORNED SUNGEM       0.93      0.93      0.93        30
#               NORTHERN JACANA       0.91      0.68      0.78        31
#          NORTHERN MOCKINGBIRD       0.69      0.89      0.78        28
#               NORTHERN PARULA       0.95      0.92      0.94        39
#           NORTHERN RED BISHOP       0.91      0.77      0.83        26
#             NORTHERN SHOVELER       0.78      0.94      0.85        31
#                       OILBIRD       1.00      0.61      0.76        36
#                  OKINAWA RAIL       0.74      0.97      0.84        32
#        ORANGE BREASTED TROGON       0.92      0.95      0.94        38
#        ORANGE BRESTED BUNTING       1.00      0.85      0.92        26
#                      OVENBIRD       0.95      0.89      0.92        47
#                OYSTER CATCHER       0.97      0.93      0.95        42
#               PAINTED BUNTING       1.00      0.88      0.94        33
#                        PALILA       0.87      0.81      0.84        32
#              PARADISE TANAGER       1.00      0.91      0.96        35
#              PARAKETT  AUKLET       0.81      0.94      0.87        31
#                   PARUS MAJOR       0.97      0.88      0.92        32
#       PATAGONIAN SIERRA FINCH       1.00      0.92      0.96        26
#                   PHAINOPEPLA       0.76      0.68      0.72        38
#                    PINK ROBIN       1.00      0.94      0.97        31
#             PLUSH CRESTED JAY       0.97      0.93      0.95        40
#               POMARINE JAEGER       0.59      0.46      0.52        28
#                        PUFFIN       0.97      0.91      0.94        33
#                     PUNA TEAL       0.75      0.81      0.78        37
#                  PURPLE FINCH       0.86      0.61      0.72        31
#              PURPLE GALLINULE       1.00      0.74      0.85        31
#                 PURPLE MARTIN       0.70      0.50      0.58        32
#                   PYRRHULOXIA       1.00      0.86      0.92        42
#                       QUETZAL       0.88      0.93      0.90        30
#              RAINBOW LORIKEET       0.97      1.00      0.98        28
#                     RAZORBILL       0.88      0.74      0.81        39
#         RED BEARDED BEE EATER       1.00      0.97      0.99        39
#             RED BELLIED PITTA       0.96      0.86      0.91        29
#         RED BILLED TROPICBIRD       0.77      0.84      0.80        43
#              RED BROWED FINCH       0.96      0.85      0.90        27
#                 RED CROSSBILL       0.97      0.74      0.84        38
#           RED FACED CORMORANT       0.79      0.61      0.69        31
#                      RED FODY       0.94      1.00      0.97        33
#               RED HEADED DUCK       1.00      0.94      0.97        32
#         RED HEADED WOODPECKER       0.88      0.85      0.87        27
#                      RED KNOT       0.81      0.65      0.72        40
#       RED LEGGED HONEYCREEPER       0.97      0.91      0.94        34
#              RED NAPED TROGON       0.96      0.84      0.90        32
#             RED TAILED THRUSH       0.89      0.92      0.91        26
#          RED WINGED BLACKBIRD       0.70      0.77      0.73        30
#           RED WISKERED BULBUL       1.00      0.94      0.97        32
#              REGENT BOWERBIRD       0.89      0.97      0.93        33
#                    ROADRUNNER       0.45      0.91      0.60        32
#                     ROCK DOVE       0.81      0.85      0.83        26
#        ROSE BREASTED COCKATOO       0.94      0.87      0.91        39
#        ROSE BREASTED GROSBEAK       0.91      0.86      0.88        35
#             ROSEATE SPOONBILL       0.92      0.85      0.88        39
#           ROSY FACED LOVEBIRD       0.96      0.93      0.95        28
#             ROUGH LEG BUZZARD       0.66      0.70      0.68        30
#                RUDDY SHELDUCK       0.88      0.91      0.90        33
#                  RUFOUS TREPE       0.92      0.89      0.90        53
#                 RUFUOS MOTMOT       0.94      0.87      0.90        38
#               SAMATRAN THRUSH       0.93      0.84      0.88        31
#                   SAND MARTIN       0.90      0.60      0.72        30
#                SATYR TRAGOPAN       0.87      1.00      0.93        34
#                   SAYS PHOEBE       0.80      0.72      0.76        39
#    SCARLET CROWNED FRUIT DOVE       0.90      0.84      0.87        31
#       SCARLET FACED LIOCICHLA       0.88      0.91      0.89        32
#                 SCARLET MACAW       0.88      0.97      0.92        31
#               SCARLET TANAGER       1.00      0.81      0.89        26
#                      SHOEBILL       0.76      0.80      0.78        35
#        SHORT BILLED DOWITCHER       0.60      0.64      0.62        33
#               SMITHS LONGSPUR       0.65      0.62      0.63        32
#                SNOW PARTRIDGE       0.74      0.57      0.65        35
#                  SNOWY PLOVER       1.00      0.65      0.79        26
#              SNOWY SHEATHBILL       0.76      0.84      0.79        37
#                          SORA       0.80      0.82      0.81        40
#              SPANGLED COTINGA       0.88      0.94      0.91        32
#         SPOON BILED SANDPIPER       0.79      0.38      0.51        29
#               SPOTTED CATBIRD       0.61      0.83      0.70        30
#        SPOTTED WHISTLING DUCK       0.64      0.78      0.71        37
#         SRI LANKA BLUE MAGPIE       0.94      0.97      0.95        32
#                  STEAMER DUCK       0.82      0.88      0.85        32
#             STRIATED CARACARA       0.88      0.77      0.82        39
#              STRIPPED MANAKIN       0.88      0.97      0.92        29
#                    SUNBITTERN       0.56      0.88      0.68        34
#               SUPERB STARLING       0.93      0.90      0.92        31
#                   SURF SCOTER       0.85      0.95      0.90        37
#                    TAILORBIRD       0.86      0.89      0.88        28
#                 TAIWAN MAGPIE       0.89      0.93      0.91        27
#                        TAKAHE       0.91      0.94      0.92        32
#               TAWNY FROGMOUTH       0.78      0.68      0.72        37
#                     TEAL DUCK       0.68      0.87      0.76        31
#                     TIT MOUSE       0.91      0.68      0.78        31
#                       TOUCHAN       0.96      1.00      0.98        27
#          TRICOLORED BLACKBIRD       0.81      0.61      0.69        28
#             TROPICAL KINGBIRD       0.85      0.90      0.88        31
#              TURQUOISE MOTMOT       0.93      0.84      0.88        31
#                 UMBRELLA BIRD       0.82      0.90      0.86        31
#                 VARIED THRUSH       0.97      0.85      0.90        39
#                         VEERY       0.87      0.87      0.87        38
#          VENEZUELIAN TROUPIAL       0.81      0.87      0.84        30
#                        VERDIN       0.97      0.78      0.86        36
#           VERMILION FLYCATHER       0.96      0.84      0.90        31
#       VICTORIA CROWNED PIGEON       0.93      0.83      0.88        30
#        VIOLET BACKED STARLING       0.91      0.80      0.85        40
#                 VIOLET CUCKOO       0.57      0.89      0.70        35
#                 VIOLET TURACO       0.86      0.97      0.91        32
#              VISAYAN HORNBILL       0.88      0.67      0.76        33
#                  WALL CREAPER       0.92      0.97      0.94        34
#               WATTLED LAPWING       0.89      0.86      0.87        28
#                      WHIMBREL       0.50      0.82      0.62        28
#            WHITE BROWED CRAKE       0.78      0.90      0.84        31
#          WHITE CHEEKED TURACO       0.72      0.68      0.70        31
#        WHITE CRESTED HORNBILL       0.89      0.53      0.67        32
#            WHITE NECKED RAVEN       0.56      0.75      0.64        32
#           WHITE TAILED TROPIC       0.55      0.60      0.58        35
#      WHITE THROATED BEE EATER       1.00      0.97      0.98        33
#              WILLOW PTARMIGAN       0.85      0.56      0.68        39
#      WILSONS BIRD OF PARADISE       1.00      0.84      0.91        31
#                     WOOD DUCK       0.86      0.98      0.91        43
#                   WOOD THRUSH       0.93      0.93      0.93        42
#   YELLOW BELLIED FLOWERPECKER       0.69      0.71      0.70        31
#          YELLOW BREASTED CHAT       0.95      1.00      0.98        40
#                YELLOW CACIQUE       0.93      0.81      0.86        31
#       YELLOW HEADED BLACKBIRD       0.91      0.94      0.92        32
#                    ZEBRA DOVE       0.65      0.88      0.75        34
#
#                      accuracy                           0.81     13292
#                     macro avg       0.83      0.81      0.82     13292
#                  weighted avg       0.83      0.81      0.82     13292

# %%
# https://keras.io/examples/vision/grad_cam/

def get_img_array(img_path, size):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=size)
    array = tf.keras.preprocessing.image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        inputs = model.inputs, outputs = [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]
    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = tf.keras.preprocessing.image.load_img(img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)
    # Save the superimposed image
    superimposed_img.save(cam_path)
    return cam_path

preprocess_input = tf.keras.applications.efficientnet.preprocess_input
decode_predictions = tf.keras.applications.efficientnet.decode_predictions

last_conv_layer_name = "conv_s1"
img_size = (80, 80, 3)

# Remove last layer's softmax
model.layers[-1].activation = None

# %%
# Let's now run predictions against the test images and show the output
# for a random subset as a grid
pred = model.predict(test_images)
pred = np.argmax(pred, axis=1)

# Map the label
labels = (test_images.class_indices)
labels = dict((v, k) for k, v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')

# Display 25 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_images.filepaths), 25)
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(25, 25), subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_images.filepaths[random_index[i]]))
    true_label = labels[test_images.classes[random_index[i]]]
    predicted_label = pred[random_index[i]]
    if true_label == predicted_label:
        color = "green"
    else:
        color = "red"
    ax.set_title(f"True: {true_label}\nPredicted: {predicted_label}", color=color)

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Display the part of the pictures used by the neural network to classify the pictures
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    img_path = test_images.filepaths[random_index[i]]
    img_array = tf.keras.applications.efficientnet.preprocess_input(get_img_array(img_path, size=img_size))
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
    cam_path = save_and_display_gradcam(img_path, heatmap)
    ax.imshow(plt.imread(cam_path))
    ax.set_title(f"True: {labels[test_images.classes[random_index[i]]]}\nPredicted: {pred[random_index[i]]}")
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Quantization
tflite_model_path = 'C:/colab/data/birds/bird_classifier_80x80_411.tflite'
test_extra_ds = "C:/colab/data/birds/test"


quantization_image_set = test_generator.flow_from_directory(
    directory=filtered_test_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True
)

def representative_dataset():
    i = 0
    for input_data, _ in quantization_image_set:
        yield [input_data]

        if i >= 19:
           break
        i += 1

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
converter.representative_dataset = representative_dataset

# Convert the model
tflite_model_int8 = converter.convert()

# Save the converted INT8 quantized model
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model_int8)
# Out:
# Found 13292 images belonging to 411 classes.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Osenin\AppData\Local\Temp\tmpbgj8lmie\assets
# INFO:tensorflow:Assets written to: C:\Users\Osenin\AppData\Local\Temp\tmpbgj8lmie\assets
# C:\Users\Osenin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "

# %%
# Using a smaller batch size
test_images = test_generator.flow_from_directory(
    directory=filtered_test_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)

tflite_interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

tflite_interpreter.resize_tensor_input(input_details[0]['index'], (32, 80, 80, 3))
tflite_interpreter.resize_tensor_input(output_details[0]['index'], (32, 5))
tflite_interpreter.allocate_tensors()

input_batch, _ = next(test_images)

results = []
average_accuracy = 0
for i in range(len(test_images)):
    batch = test_images[i]
    input_batch, labels = batch
    image_input_batch = tf.cast(input_batch, tf.int8)

    input_scale, input_zero_point = input_details[0]["quantization"]
    image_input_batch = tf.cast(image_input_batch, tf.float32)
    image_input_batch = (image_input_batch / input_scale) + input_zero_point
    image_input_batch = tf.cast(image_input_batch, tf.int8)
    if len(image_input_batch) == 32:
        tflite_interpreter.set_tensor(input_details[0]['index'], image_input_batch)
        tflite_interpreter.invoke()
        tflite_model_predictions = tflite_interpreter.get_tensor(output_details[0]['index'])

        tflite_predicted_ids = np.argmax(tflite_model_predictions, axis=-1)
        tflite_label_id = np.argmax(labels, axis=-1)

        correct_predictions = np.sum(tflite_predicted_ids == tflite_label_id)
        total_predictions = len(tflite_predicted_ids)
        accuracy_percentage = (correct_predictions / total_predictions) * 100

        results.append(accuracy_percentage)
        average_accuracy = sum(results) / len(results)
        print("\nIteration ", i, ": ", accuracy_percentage, " - Running Average: ", average_accuracy)

print("\nEnd Average: ", average_accuracy)
# Out:
# Found 13292 images belonging to 411 classes.
#
# Iteration  0 :  71.875  - Running Average:  71.875
#
# Iteration  1 :  46.875  - Running Average:  59.375
#
# Iteration  2 :  81.25  - Running Average:  66.66666666666667
#
# Iteration  3 :  56.25  - Running Average:  64.0625
#
# Iteration  4 :  84.375  - Running Average:  68.125
#
# Iteration  5 :  90.625  - Running Average:  71.875
#
# Iteration  6 :  62.5  - Running Average:  70.53571428571429
#
# Iteration  7 :  62.5  - Running Average:  69.53125
#
# Iteration  8 :  62.5  - Running Average:  68.75
#
# Iteration  9 :  90.625  - Running Average:  70.9375
#
# Iteration  10 :  81.25  - Running Average:  71.875
#
# Iteration  11 :  84.375  - Running Average:  72.91666666666667
#
# Iteration  12 :  90.625  - Running Average:  74.27884615384616
#
# Iteration  13 :  78.125  - Running Average:  74.55357142857143
#
# Iteration  14 :  81.25  - Running Average:  75.0
#
# Iteration  15 :  75.0  - Running Average:  75.0
#
# Iteration  16 :  84.375  - Running Average:  75.55147058823529
#
# Iteration  17 :  78.125  - Running Average:  75.69444444444444
#
# Iteration  18 :  75.0  - Running Average:  75.65789473684211
#
# Iteration  19 :  81.25  - Running Average:  75.9375
#
# Iteration  20 :  78.125  - Running Average:  76.04166666666667
#
# Iteration  21 :  65.625  - Running Average:  75.56818181818181
#
# Iteration  22 :  78.125  - Running Average:  75.67934782608695
#
# Iteration  23 :  62.5  - Running Average:  75.13020833333333
#
# Iteration  24 :  75.0  - Running Average:  75.125
#
# Iteration  25 :  87.5  - Running Average:  75.60096153846153
#
# Iteration  26 :  75.0  - Running Average:  75.57870370370371
#
# Iteration  27 :  75.0  - Running Average:  75.55803571428571
#
# Iteration  28 :  68.75  - Running Average:  75.32327586206897
#
# Iteration  29 :  75.0  - Running Average:  75.3125
#
# Iteration  30 :  81.25  - Running Average:  75.50403225806451
#
# Iteration  31 :  75.0  - Running Average:  75.48828125
#
# Iteration  32 :  59.375  - Running Average:  75.0
#
# Iteration  33 :  71.875  - Running Average:  74.90808823529412
#
# Iteration  34 :  78.125  - Running Average:  75.0
#
# Iteration  35 :  100.0  - Running Average:  75.69444444444444
#
# Iteration  36 :  37.5  - Running Average:  74.66216216216216
#
# Iteration  37 :  56.25  - Running Average:  74.17763157894737
#
# Iteration  38 :  84.375  - Running Average:  74.43910256410257
#
# Iteration  39 :  81.25  - Running Average:  74.609375
#
# Iteration  40 :  78.125  - Running Average:  74.6951219512195
#
# Iteration  41 :  90.625  - Running Average:  75.07440476190476
#
# Iteration  42 :  75.0  - Running Average:  75.07267441860465
#
# Iteration  43 :  87.5  - Running Average:  75.35511363636364
#
# Iteration  44 :  68.75  - Running Average:  75.20833333333333
#
# Iteration  45 :  84.375  - Running Average:  75.40760869565217
#
# Iteration  46 :  96.875  - Running Average:  75.86436170212765
#
# Iteration  47 :  87.5  - Running Average:  76.10677083333333
#
# Iteration  48 :  87.5  - Running Average:  76.33928571428571
#
# Iteration  49 :  90.625  - Running Average:  76.625
#
# Iteration  50 :  84.375  - Running Average:  76.77696078431373
#
# Iteration  51 :  96.875  - Running Average:  77.16346153846153
#
# Iteration  52 :  84.375  - Running Average:  77.2995283018868
#
# Iteration  53 :  81.25  - Running Average:  77.37268518518519
#
# Iteration  54 :  62.5  - Running Average:  77.10227272727273
#
# Iteration  55 :  93.75  - Running Average:  77.39955357142857
#
# Iteration  56 :  93.75  - Running Average:  77.68640350877193
#
# Iteration  57 :  84.375  - Running Average:  77.80172413793103
#
# Iteration  58 :  78.125  - Running Average:  77.8072033898305
#
# Iteration  59 :  93.75  - Running Average:  78.07291666666667
#
# Iteration  60 :  87.5  - Running Average:  78.22745901639344
#
# Iteration  61 :  65.625  - Running Average:  78.0241935483871
#
# Iteration  62 :  65.625  - Running Average:  77.82738095238095
#
# Iteration  63 :  65.625  - Running Average:  77.63671875
#
# Iteration  64 :  78.125  - Running Average:  77.64423076923077
#
# Iteration  65 :  81.25  - Running Average:  77.69886363636364
#
# Iteration  66 :  81.25  - Running Average:  77.7518656716418
#
# Iteration  67 :  78.125  - Running Average:  77.75735294117646
#
# Iteration  68 :  93.75  - Running Average:  77.98913043478261
#
# Iteration  69 :  96.875  - Running Average:  78.25892857142857
#
# Iteration  70 :  84.375  - Running Average:  78.34507042253522
#
# Iteration  71 :  65.625  - Running Average:  78.16840277777777
#
# Iteration  72 :  87.5  - Running Average:  78.29623287671232
#
# Iteration  73 :  93.75  - Running Average:  78.50506756756756
#
# Iteration  74 :  93.75  - Running Average:  78.70833333333333
#
# Iteration  75 :  90.625  - Running Average:  78.86513157894737
#
# Iteration  76 :  81.25  - Running Average:  78.8961038961039
#
# Iteration  77 :  78.125  - Running Average:  78.88621794871794
#
# Iteration  78 :  90.625  - Running Average:  79.03481012658227
#
# Iteration  79 :  87.5  - Running Average:  79.140625
#
# Iteration  80 :  78.125  - Running Average:  79.12808641975309
#
# Iteration  81 :  65.625  - Running Average:  78.96341463414635
#
# Iteration  82 :  71.875  - Running Average:  78.87801204819277
#
# Iteration  83 :  78.125  - Running Average:  78.86904761904762
#
# Iteration  84 :  87.5  - Running Average:  78.97058823529412
#
# Iteration  85 :  81.25  - Running Average:  78.99709302325581
#
# Iteration  86 :  84.375  - Running Average:  79.058908045977
#
# Iteration  87 :  78.125  - Running Average:  79.04829545454545
#
# Iteration  88 :  65.625  - Running Average:  78.89747191011236
#
# Iteration  89 :  56.25  - Running Average:  78.64583333333333
#
# Iteration  90 :  59.375  - Running Average:  78.43406593406593
#
# Iteration  91 :  65.625  - Running Average:  78.29483695652173
#
# Iteration  92 :  81.25  - Running Average:  78.32661290322581
#
# Iteration  93 :  93.75  - Running Average:  78.49069148936171
#
# Iteration  94 :  75.0  - Running Average:  78.45394736842105
#
# Iteration  95 :  68.75  - Running Average:  78.35286458333333
#
# Iteration  96 :  56.25  - Running Average:  78.125
#
# Iteration  97 :  78.125  - Running Average:  78.125
#
# Iteration  98 :  56.25  - Running Average:  77.9040404040404
#
# Iteration  99 :  96.875  - Running Average:  78.09375
#
# Iteration  100 :  90.625  - Running Average:  78.21782178217822
#
# Iteration  101 :  68.75  - Running Average:  78.125
#
# Iteration  102 :  81.25  - Running Average:  78.15533980582525
#
# Iteration  103 :  90.625  - Running Average:  78.27524038461539
#
# Iteration  104 :  93.75  - Running Average:  78.42261904761905
#
# Iteration  105 :  90.625  - Running Average:  78.5377358490566
#
# Iteration  106 :  93.75  - Running Average:  78.67990654205607
#
# Iteration  107 :  93.75  - Running Average:  78.81944444444444
#
# Iteration  108 :  93.75  - Running Average:  78.95642201834862
#
# Iteration  109 :  87.5  - Running Average:  79.0340909090909
#
# Iteration  110 :  93.75  - Running Average:  79.16666666666667
#
# Iteration  111 :  68.75  - Running Average:  79.07366071428571
#
# Iteration  112 :  75.0  - Running Average:  79.03761061946902
#
# Iteration  113 :  87.5  - Running Average:  79.11184210526316
#
# Iteration  114 :  75.0  - Running Average:  79.07608695652173
#
# Iteration  115 :  87.5  - Running Average:  79.14870689655173
#
# Iteration  116 :  68.75  - Running Average:  79.05982905982906
#
# Iteration  117 :  90.625  - Running Average:  79.15783898305085
#
# Iteration  118 :  81.25  - Running Average:  79.17542016806723
#
# Iteration  119 :  78.125  - Running Average:  79.16666666666667
#
# Iteration  120 :  78.125  - Running Average:  79.15805785123968
#
# Iteration  121 :  81.25  - Running Average:  79.17520491803279
#
# Iteration  122 :  96.875  - Running Average:  79.3191056910569
#
# Iteration  123 :  93.75  - Running Average:  79.43548387096774
#
# Iteration  124 :  84.375  - Running Average:  79.475
#
# Iteration  125 :  87.5  - Running Average:  79.53869047619048
#
# Iteration  126 :  81.25  - Running Average:  79.55216535433071
#
# Iteration  127 :  84.375  - Running Average:  79.58984375
#
# Iteration  128 :  81.25  - Running Average:  79.60271317829458
#
# Iteration  129 :  68.75  - Running Average:  79.51923076923077
#
# Iteration  130 :  84.375  - Running Average:  79.55629770992367
#
# Iteration  131 :  90.625  - Running Average:  79.64015151515152
#
# Iteration  132 :  84.375  - Running Average:  79.67575187969925
#
# Iteration  133 :  90.625  - Running Average:  79.75746268656717
#
# Iteration  134 :  81.25  - Running Average:  79.76851851851852
#
# Iteration  135 :  78.125  - Running Average:  79.7564338235294
#
# Iteration  136 :  71.875  - Running Average:  79.69890510948905
#
# Iteration  137 :  84.375  - Running Average:  79.73278985507247
#
# Iteration  138 :  87.5  - Running Average:  79.7886690647482
#
# Iteration  139 :  90.625  - Running Average:  79.86607142857143
#
# Iteration  140 :  84.375  - Running Average:  79.89804964539007
#
# Iteration  141 :  56.25  - Running Average:  79.73151408450704
#
# Iteration  142 :  81.25  - Running Average:  79.74213286713287
#
# Iteration  143 :  93.75  - Running Average:  79.83940972222223
#
# Iteration  144 :  75.0  - Running Average:  79.80603448275862
#
# Iteration  145 :  93.75  - Running Average:  79.90154109589041
#
# Iteration  146 :  78.125  - Running Average:  79.88945578231292
#
# Iteration  147 :  75.0  - Running Average:  79.85641891891892
#
# Iteration  148 :  96.875  - Running Average:  79.97063758389261
#
# Iteration  149 :  84.375  - Running Average:  80.0
#
# Iteration  150 :  81.25  - Running Average:  80.00827814569537
#
# Iteration  151 :  90.625  - Running Average:  80.078125
#
# Iteration  152 :  71.875  - Running Average:  80.02450980392157
#
# Iteration  153 :  78.125  - Running Average:  80.01217532467533
#
# Iteration  154 :  81.25  - Running Average:  80.02016129032258
#
# Iteration  155 :  71.875  - Running Average:  79.96794871794872
#
# Iteration  156 :  62.5  - Running Average:  79.85668789808918
#
# Iteration  157 :  87.5  - Running Average:  79.90506329113924
#
# Iteration  158 :  65.625  - Running Average:  79.81525157232704
#
# Iteration  159 :  81.25  - Running Average:  79.82421875
#
# Iteration  160 :  87.5  - Running Average:  79.8718944099379
#
# Iteration  161 :  65.625  - Running Average:  79.78395061728395
#
# Iteration  162 :  81.25  - Running Average:  79.79294478527608
#
# Iteration  163 :  84.375  - Running Average:  79.82088414634147
#
# Iteration  164 :  90.625  - Running Average:  79.88636363636364
#
# Iteration  165 :  81.25  - Running Average:  79.894578313253
#
# Iteration  166 :  75.0  - Running Average:  79.86526946107784
#
# Iteration  167 :  62.5  - Running Average:  79.76190476190476
#
# Iteration  168 :  75.0  - Running Average:  79.73372781065089
#
# Iteration  169 :  96.875  - Running Average:  79.8345588235294
#
# Iteration  170 :  84.375  - Running Average:  79.86111111111111
#
# Iteration  171 :  75.0  - Running Average:  79.8328488372093
#
# Iteration  172 :  96.875  - Running Average:  79.93135838150289
#
# Iteration  173 :  81.25  - Running Average:  79.9389367816092
#
# Iteration  174 :  84.375  - Running Average:  79.96428571428571
#
# Iteration  175 :  87.5  - Running Average:  80.00710227272727
#
# Iteration  176 :  87.5  - Running Average:  80.04943502824858
#
# Iteration  177 :  78.125  - Running Average:  80.03862359550561
#
# Iteration  178 :  87.5  - Running Average:  80.08030726256983
#
# Iteration  179 :  81.25  - Running Average:  80.08680555555556
#
# Iteration  180 :  71.875  - Running Average:  80.04143646408839
#
# Iteration  181 :  71.875  - Running Average:  79.99656593406593
#
# Iteration  182 :  78.125  - Running Average:  79.98633879781421
#
# Iteration  183 :  90.625  - Running Average:  80.04415760869566
#
# Iteration  184 :  81.25  - Running Average:  80.05067567567568
#
# Iteration  185 :  84.375  - Running Average:  80.0739247311828
#
# Iteration  186 :  71.875  - Running Average:  80.03008021390374
#
# Iteration  187 :  78.125  - Running Average:  80.01994680851064
#
# Iteration  188 :  84.375  - Running Average:  80.04298941798942
#
# Iteration  189 :  93.75  - Running Average:  80.11513157894737
#
# Iteration  190 :  90.625  - Running Average:  80.17015706806282
#
# Iteration  191 :  78.125  - Running Average:  80.15950520833333
#
# Iteration  192 :  46.875  - Running Average:  79.98704663212435
#
# Iteration  193 :  81.25  - Running Average:  79.99355670103093
#
# Iteration  194 :  71.875  - Running Average:  79.95192307692308
#
# Iteration  195 :  84.375  - Running Average:  79.97448979591837
#
# Iteration  196 :  90.625  - Running Average:  80.02855329949239
#
# Iteration  197 :  90.625  - Running Average:  80.08207070707071
#
# Iteration  198 :  81.25  - Running Average:  80.08793969849246
#
# Iteration  199 :  84.375  - Running Average:  80.109375
#
# Iteration  200 :  71.875  - Running Average:  80.06840796019901
#
# Iteration  201 :  78.125  - Running Average:  80.05878712871286
#
# Iteration  202 :  87.5  - Running Average:  80.0954433497537
#
# Iteration  203 :  100.0  - Running Average:  80.19301470588235
#
# Iteration  204 :  93.75  - Running Average:  80.25914634146342
#
# Iteration  205 :  40.625  - Running Average:  80.06674757281553
#
# Iteration  206 :  46.875  - Running Average:  79.90640096618357
#
# Iteration  207 :  31.25  - Running Average:  79.67247596153847
#
# Iteration  208 :  50.0  - Running Average:  79.5305023923445
#
# Iteration  209 :  81.25  - Running Average:  79.53869047619048
#
# Iteration  210 :  93.75  - Running Average:  79.60604265402844
#
# Iteration  211 :  87.5  - Running Average:  79.6432783018868
#
# Iteration  212 :  93.75  - Running Average:  79.70950704225352
#
# Iteration  213 :  71.875  - Running Average:  79.67289719626169
#
# Iteration  214 :  75.0  - Running Average:  79.65116279069767
#
# Iteration  215 :  87.5  - Running Average:  79.6875
#
# Iteration  216 :  87.5  - Running Average:  79.72350230414746
#
# Iteration  217 :  75.0  - Running Average:  79.70183486238533
#
# Iteration  218 :  87.5  - Running Average:  79.73744292237443
#
# Iteration  219 :  78.125  - Running Average:  79.73011363636364
#
# Iteration  220 :  78.125  - Running Average:  79.72285067873302
#
# Iteration  221 :  68.75  - Running Average:  79.67342342342343
#
# Iteration  222 :  81.25  - Running Average:  79.6804932735426
#
# Iteration  223 :  90.625  - Running Average:  79.72935267857143
#
# Iteration  224 :  71.875  - Running Average:  79.69444444444444
#
# Iteration  225 :  90.625  - Running Average:  79.74280973451327
#
# Iteration  226 :  96.875  - Running Average:  79.818281938326
#
# Iteration  227 :  81.25  - Running Average:  79.82456140350877
#
# Iteration  228 :  75.0  - Running Average:  79.80349344978166
#
# Iteration  229 :  90.625  - Running Average:  79.85054347826087
#
# Iteration  230 :  68.75  - Running Average:  79.80248917748918
#
# Iteration  231 :  81.25  - Running Average:  79.80872844827586
#
# Iteration  232 :  90.625  - Running Average:  79.85515021459227
#
# Iteration  233 :  81.25  - Running Average:  79.86111111111111
#
# Iteration  234 :  59.375  - Running Average:  79.77393617021276
#
# Iteration  235 :  84.375  - Running Average:  79.79343220338983
#
# Iteration  236 :  90.625  - Running Average:  79.83913502109705
#
# Iteration  237 :  53.125  - Running Average:  79.72689075630252
#
# Iteration  238 :  75.0  - Running Average:  79.7071129707113
#
# Iteration  239 :  75.0  - Running Average:  79.6875
#
# Iteration  240 :  96.875  - Running Average:  79.75881742738589
#
# Iteration  241 :  96.875  - Running Average:  79.82954545454545
#
# Iteration  242 :  93.75  - Running Average:  79.88683127572017
#
# Iteration  243 :  75.0  - Running Average:  79.86680327868852
#
# Iteration  244 :  81.25  - Running Average:  79.87244897959184
#
# Iteration  245 :  87.5  - Running Average:  79.90345528455285
#
# Iteration  246 :  84.375  - Running Average:  79.92155870445345
#
# Iteration  247 :  84.375  - Running Average:  79.93951612903226
#
# Iteration  248 :  100.0  - Running Average:  80.02008032128514
#
# Iteration  249 :  53.125  - Running Average:  79.9125
#
# Iteration  250 :  78.125  - Running Average:  79.90537848605578
#
# Iteration  251 :  90.625  - Running Average:  79.94791666666667
#
# Iteration  252 :  100.0  - Running Average:  80.02717391304348
#
# Iteration  253 :  81.25  - Running Average:  80.03198818897638
#
# Iteration  254 :  90.625  - Running Average:  80.07352941176471
#
# Iteration  255 :  84.375  - Running Average:  80.09033203125
#
# Iteration  256 :  81.25  - Running Average:  80.09484435797665
#
# Iteration  257 :  71.875  - Running Average:  80.06298449612403
#
# Iteration  258 :  81.25  - Running Average:  80.06756756756756
#
# Iteration  259 :  81.25  - Running Average:  80.07211538461539
#
# Iteration  260 :  71.875  - Running Average:  80.04070881226053
#
# Iteration  261 :  71.875  - Running Average:  80.00954198473282
#
# Iteration  262 :  81.25  - Running Average:  80.01425855513308
#
# Iteration  263 :  68.75  - Running Average:  79.9715909090909
#
# Iteration  264 :  84.375  - Running Average:  79.98820754716981
#
# Iteration  265 :  78.125  - Running Average:  79.9812030075188
#
# Iteration  266 :  87.5  - Running Average:  80.00936329588015
#
# Iteration  267 :  87.5  - Running Average:  80.03731343283582
#
# Iteration  268 :  78.125  - Running Average:  80.03020446096654
#
# Iteration  269 :  71.875  - Running Average:  80.0
#
# Iteration  270 :  84.375  - Running Average:  80.01614391143912
#
# Iteration  271 :  78.125  - Running Average:  80.0091911764706
#
# Iteration  272 :  75.0  - Running Average:  79.9908424908425
#
# Iteration  273 :  93.75  - Running Average:  80.04105839416059
#
# Iteration  274 :  71.875  - Running Average:  80.01136363636364
#
# Iteration  275 :  75.0  - Running Average:  79.99320652173913
#
# Iteration  276 :  62.5  - Running Average:  79.93005415162455
#
# Iteration  277 :  46.875  - Running Average:  79.81115107913669
#
# Iteration  278 :  65.625  - Running Average:  79.7603046594982
#
# Iteration  279 :  65.625  - Running Average:  79.70982142857143
#
# Iteration  280 :  87.5  - Running Average:  79.73754448398577
#
# Iteration  281 :  59.375  - Running Average:  79.66533687943263
#
# Iteration  282 :  81.25  - Running Average:  79.67093639575971
#
# Iteration  283 :  90.625  - Running Average:  79.70950704225352
#
# Iteration  284 :  56.25  - Running Average:  79.62719298245614
#
# Iteration  285 :  37.5  - Running Average:  79.4798951048951
#
# Iteration  286 :  96.875  - Running Average:  79.54050522648083
#
# Iteration  287 :  78.125  - Running Average:  79.53559027777777
#
# Iteration  288 :  46.875  - Running Average:  79.42257785467127
#
# Iteration  289 :  65.625  - Running Average:  79.375
#
# Iteration  290 :  71.875  - Running Average:  79.34922680412372
#
# Iteration  291 :  87.5  - Running Average:  79.3771404109589
#
# Iteration  292 :  84.375  - Running Average:  79.39419795221843
#
# Iteration  293 :  87.5  - Running Average:  79.421768707483
#
# Iteration  294 :  78.125  - Running Average:  79.41737288135593
#
# Iteration  295 :  62.5  - Running Average:  79.3602195945946
#
# Iteration  296 :  100.0  - Running Average:  79.4297138047138
#
# Iteration  297 :  93.75  - Running Average:  79.47776845637584
#
# Iteration  298 :  84.375  - Running Average:  79.49414715719064
#
# Iteration  299 :  81.25  - Running Average:  79.5
#
# Iteration  300 :  84.375  - Running Average:  79.51619601328903
#
# Iteration  301 :  93.75  - Running Average:  79.56332781456953
#
# Iteration  302 :  81.25  - Running Average:  79.56889438943894
#
# Iteration  303 :  90.625  - Running Average:  79.60526315789474
#
# Iteration  304 :  96.875  - Running Average:  79.66188524590164
#
# Iteration  305 :  84.375  - Running Average:  79.67728758169935
#
# Iteration  306 :  84.375  - Running Average:  79.69258957654723
#
# Iteration  307 :  71.875  - Running Average:  79.66720779220779
#
# Iteration  308 :  71.875  - Running Average:  79.64199029126213
#
# Iteration  309 :  93.75  - Running Average:  79.6875
#
# Iteration  310 :  75.0  - Running Average:  79.67242765273312
#
# Iteration  311 :  59.375  - Running Average:  79.6073717948718
#
# Iteration  312 :  96.875  - Running Average:  79.66253993610223
#
# Iteration  313 :  65.625  - Running Average:  79.61783439490446
#
# Iteration  314 :  71.875  - Running Average:  79.59325396825396
#
# Iteration  315 :  65.625  - Running Average:  79.54905063291139
#
# Iteration  316 :  65.625  - Running Average:  79.5051261829653
#
# Iteration  317 :  78.125  - Running Average:  79.50078616352201
#
# Iteration  318 :  84.375  - Running Average:  79.516065830721
#
# Iteration  319 :  93.75  - Running Average:  79.560546875
#
# Iteration  320 :  68.75  - Running Average:  79.52686915887851
#
# Iteration  321 :  93.75  - Running Average:  79.57104037267081
#
# Iteration  322 :  96.875  - Running Average:  79.62461300309597
#
# Iteration  323 :  75.0  - Running Average:  79.61033950617283
#
# Iteration  324 :  90.625  - Running Average:  79.64423076923077
#
# Iteration  325 :  68.75  - Running Average:  79.61081288343559
#
# Iteration  326 :  68.75  - Running Average:  79.5775993883792
#
# Iteration  327 :  71.875  - Running Average:  79.55411585365853
#
# Iteration  328 :  96.875  - Running Average:  79.60676291793312
#
# Iteration  329 :  87.5  - Running Average:  79.63068181818181
#
# Iteration  330 :  71.875  - Running Average:  79.60725075528701
#
# Iteration  331 :  68.75  - Running Average:  79.57454819277109
#
# Iteration  332 :  87.5  - Running Average:  79.59834834834835
#
# Iteration  333 :  84.375  - Running Average:  79.61264970059881
#
# Iteration  334 :  81.25  - Running Average:  79.61753731343283
#
# Iteration  335 :  87.5  - Running Average:  79.64099702380952
#
# Iteration  336 :  100.0  - Running Average:  79.70140949554896
#
# Iteration  337 :  75.0  - Running Average:  79.6875
#
# Iteration  338 :  90.625  - Running Average:  79.71976401179941
#
# Iteration  339 :  84.375  - Running Average:  79.73345588235294
#
# Iteration  340 :  93.75  - Running Average:  79.77456011730206
#
# Iteration  341 :  84.375  - Running Average:  79.78801169590643
#
# Iteration  342 :  93.75  - Running Average:  79.82871720116619
#
# Iteration  343 :  81.25  - Running Average:  79.8328488372093
#
# Iteration  344 :  68.75  - Running Average:  79.80072463768116
#
# Iteration  345 :  87.5  - Running Average:  79.82297687861272
#
# Iteration  346 :  84.375  - Running Average:  79.83609510086455
#
# Iteration  347 :  81.25  - Running Average:  79.840158045977
#
# Iteration  348 :  81.25  - Running Average:  79.84419770773638
#
# Iteration  349 :  78.125  - Running Average:  79.83928571428571
#
# Iteration  350 :  62.5  - Running Average:  79.78988603988604
#
# Iteration  351 :  78.125  - Running Average:  79.78515625
#
# Iteration  352 :  75.0  - Running Average:  79.77160056657223
#
# Iteration  353 :  78.125  - Running Average:  79.76694915254237
#
# Iteration  354 :  93.75  - Running Average:  79.80633802816901
#
# Iteration  355 :  93.75  - Running Average:  79.84550561797752
#
# Iteration  356 :  71.875  - Running Average:  79.82317927170868
#
# Iteration  357 :  68.75  - Running Average:  79.79224860335195
#
# Iteration  358 :  46.875  - Running Average:  79.70055710306407
#
# Iteration  359 :  53.125  - Running Average:  79.62673611111111
#
# Iteration  360 :  43.75  - Running Average:  79.52735457063712
#
# Iteration  361 :  62.5  - Running Average:  79.48031767955801
#
# Iteration  362 :  78.125  - Running Average:  79.47658402203857
#
# Iteration  363 :  75.0  - Running Average:  79.46428571428571
#
# Iteration  364 :  87.5  - Running Average:  79.48630136986301
#
# Iteration  365 :  37.5  - Running Average:  79.37158469945355
#
# Iteration  366 :  75.0  - Running Average:  79.35967302452316
#
# Iteration  367 :  78.125  - Running Average:  79.35631793478261
#
# Iteration  368 :  96.875  - Running Average:  79.40379403794039
#
# Iteration  369 :  84.375  - Running Average:  79.41722972972973
#
# Iteration  370 :  78.125  - Running Average:  79.41374663072776
#
# Iteration  371 :  93.75  - Running Average:  79.45228494623656
#
# Iteration  372 :  84.375  - Running Average:  79.46548257372655
#
# Iteration  373 :  96.875  - Running Average:  79.5120320855615
#
# Iteration  374 :  87.5  - Running Average:  79.53333333333333
#
# Iteration  375 :  87.5  - Running Average:  79.55452127659575
#
# Iteration  376 :  81.25  - Running Average:  79.55901856763926
#
# Iteration  377 :  81.25  - Running Average:  79.56349206349206
#
# Iteration  378 :  56.25  - Running Average:  79.50197889182058
#
# Iteration  379 :  84.375  - Running Average:  79.51480263157895
#
# Iteration  380 :  59.375  - Running Average:  79.46194225721784
#
# Iteration  381 :  90.625  - Running Average:  79.49116492146597
#
# Iteration  382 :  59.375  - Running Average:  79.43864229765013
#
# Iteration  383 :  90.625  - Running Average:  79.4677734375
#
# Iteration  384 :  87.5  - Running Average:  79.48863636363636
#
# Iteration  385 :  81.25  - Running Average:  79.49319948186529
#
# Iteration  386 :  84.375  - Running Average:  79.50581395348837
#
# Iteration  387 :  78.125  - Running Average:  79.50225515463917
#
# Iteration  388 :  75.0  - Running Average:  79.49068123393316
#
# Iteration  389 :  78.125  - Running Average:  79.48717948717949
#
# Iteration  390 :  81.25  - Running Average:  79.49168797953965
#
# Iteration  391 :  81.25  - Running Average:  79.49617346938776
#
# Iteration  392 :  75.0  - Running Average:  79.48473282442748
#
# Iteration  393 :  87.5  - Running Average:  79.50507614213198
#
# Iteration  394 :  90.625  - Running Average:  79.53322784810126
#
# Iteration  395 :  75.0  - Running Average:  79.5217803030303
#
# Iteration  396 :  84.375  - Running Average:  79.53400503778337
#
# Iteration  397 :  87.5  - Running Average:  79.55402010050251
#
# Iteration  398 :  75.0  - Running Average:  79.54260651629073
#
# Iteration  399 :  71.875  - Running Average:  79.5234375
#
# Iteration  400 :  68.75  - Running Average:  79.4965710723192
#
# Iteration  401 :  59.375  - Running Average:  79.44651741293532
#
# Iteration  402 :  62.5  - Running Average:  79.40446650124069
#
# Iteration  403 :  59.375  - Running Average:  79.35488861386139
#
# Iteration  404 :  81.25  - Running Average:  79.35956790123457
#
# Iteration  405 :  68.75  - Running Average:  79.33343596059113
#
# Iteration  406 :  53.125  - Running Average:  79.26904176904176
#
# Iteration  407 :  96.875  - Running Average:  79.31219362745098
#
# Iteration  408 :  100.0  - Running Average:  79.3627750611247
#
# Iteration  409 :  75.0  - Running Average:  79.35213414634147
#
# Iteration  410 :  68.75  - Running Average:  79.32633819951339
#
# Iteration  411 :  93.75  - Running Average:  79.36134708737865
#
# Iteration  412 :  84.375  - Running Average:  79.37348668280872
#
# Iteration  413 :  90.625  - Running Average:  79.40066425120773
#
# Iteration  414 :  93.75  - Running Average:  79.43524096385542
#
# End Average:  79.43524096385542
