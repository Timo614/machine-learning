# %% [markdown]
# Total params: 190,770
#
# Training Accuracy: 96.33%
#
# Validation Accuracy: 87.15%
#
# Test Accuracy: 85.05%
#
# Quantization Accuracy: 74.16% (74.164%)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import shutil
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report
from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Conv2D
from tensorflow.keras.optimizers import Adam

# %%
BATCH_SIZE = 128
# You may need to lower this depending upon your GPU

TARGET_SIZE = (96, 96)
# This model uses 96x96 images

# %%
# These were created as part of our data preparation notebook
filtered_train_storage_ds = "C:/colab/data/birds/cached/filtered/train"
filtered_valid_storage_ds = "C:/colab/data/birds/cached/filtered/valid"
filtered_test_storage_ds = "C:/colab/data/birds/cached/filtered/test"

# %%
# Generator
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    brightness_range=[0.75,1.15],
    rotation_range=30,
    channel_shift_range=10,
    width_shift_range=1.0,
    height_shift_range=1.0,
    shear_range=0.02,
    horizontal_flip=True,
    fill_mode='reflect',
)

# Many folks are against validation augmentation but I use it as the changes
# here are mostly minimal and gives more variation. The test generator is pure.
validation_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    brightness_range=[0.75,1.15],
    rotation_range=30,
    channel_shift_range=10,
    fill_mode='reflect',
    validation_split=0.2,
    horizontal_flip=True,
)


test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
train_images = train_generator.flow_from_directory(
    directory=filtered_train_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed=42,
    shuffle=True,
)

val_images = validation_generator.flow_from_directory(
    directory=filtered_valid_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed=42,
    shuffle=True,
)

test_images = test_generator.flow_from_directory(
    directory=filtered_test_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 42596 images belonging to 411 classes.
# Found 10554 images belonging to 411 classes.
# Found 13292 images belonging to 411 classes.

# %%
# Visualize the images
def visualize_generator(generator, samples = 5):
    batch_images, labels = next(generator)
    plt.figure(figsize=(10,5))
    for i in range(samples):
        plt.subplot(1, samples, i+1)
        plt.imshow(batch_images[i] / 255.0)
        plt.axis('off')
    plt.show()
    batch_images, labels = next(generator)
    plt.figure(figsize=(10,5))
    for i in range(samples):
        plt.subplot(1, samples, i+1)
        plt.imshow(batch_images[i+5] / 255.0)
        plt.axis('off')
    plt.show()
    batch_images, labels = next(generator)
    plt.figure(figsize=(10,5))
    for i in range(samples):
        plt.subplot(1, samples, i+1)
        plt.imshow(batch_images[i+10] / 255.0)
        plt.axis('off')
    plt.show()

print("Train images:")
visualize_generator(train_images)

print("Validation images:")
visualize_generator(val_images)

print("Test images:")
visualize_generator(test_images)
# Out:
# Train images:
# Validation images:
# Test images:

# %%
# absolute-cosine regularization
# https://www.amazon.science/publications/quantization-aware-training-with-absolute-cosine-regularization-for-automatic-speech-recognition
class ACosR(tf.keras.regularizers.Regularizer):
    def __init__(self, weight=1.0):
        self.weight = weight

    def __call__(self, weights):
        # Calculate the absolute cosine similarity
        cos_similarity = tf.reduce_mean(tf.abs(tf.reduce_sum(weights * tf.roll(weights, shift=1, axis=-1), axis=-1)))

        # Apply the regularization term to the loss
        regularization_loss = self.weight * cos_similarity

        return regularization_loss

    def get_config(self):
        return {'weight': float(self.weight)}

# %%
# Load the pretrained model
pretrained_model = tf.keras.applications.EfficientNetB0(input_shape=(96, 96, 3), include_top=False, weights='imagenet')
pretrained_model.trainable = False
selected_layer_index = 87
pretrained_model.layers[2]._name = 'normalization'

# Enable ACosR
for i in range(0, len(pretrained_model.layers)):
    layer = pretrained_model.layers[i]
    if isinstance(layer, keras.layers.Conv2D) or isinstance(layer, keras.layers.DepthwiseConv2D):
        pretrained_model.layers[i].kernel_regularizer = ACosR(weight = 0.005)

for i in range(0, len(pretrained_model.layers)):
    if hasattr(pretrained_model.layers[i], "activation"):
        if "swish" in str(pretrained_model.layers[i].activation):
            pretrained_model.layers[i].activation = tf.keras.activations.relu

selected_layer_output = pretrained_model.layers[selected_layer_index].output
x = selected_layer_output
x = Conv2D(240, 1, groups=2, trainable=False, name="conv_s1", padding='valid', kernel_regularizer = ACosR(weight = 0.005))(x)
x = tf.keras.layers.BatchNormalization(trainable = False, name='tbd-b1')(x)
x = tf.keras.layers.Activation(tf.keras.activations.relu)(x)

x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = Dense(180, trainable = False, kernel_regularizer = ACosR(weight = 0.005), name="dense_s_1", activation='relu')(x)
x = Dense(50, trainable = False, kernel_regularizer = ACosR(weight = 0.005), name="dense_2", activation='relu')(x)
outputs = Dense(411, kernel_regularizer = ACosR(weight = 0.005), trainable = False, activation=tf.keras.activations.softmax, name="dense_output")(x)
model = Model(inputs=pretrained_model.input, outputs=outputs)
model.load_weights('C:/colab/data/birds/saves/96x96_411_full_relu_post_decimation/saved_model')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 96, 96, 3)    0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 96, 96, 3)    7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 96, 96, 3)    0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 97, 97, 3)    0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 48, 48, 32)   864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 48, 48, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 48, 48, 32)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 48, 48, 32)  288         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 48, 48, 32)  128         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 48, 48, 32)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 48, 48, 32)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 48, 48, 16)   512         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 48, 48, 16)  64          ['block1a_project_conv[0][0]']
#  lization)
#
#  block2a_expand_conv (Conv2D)   (None, 48, 48, 96)   1536        ['block1a_project_bn[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 48, 48, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 48, 48, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 49, 49, 96)  0           ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 24, 24, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 24, 24, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 24, 24, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 24, 24, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 24, 24, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 24, 24, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 24, 24, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 24, 24, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 24, 24, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 24, 24, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 24, 24, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 24, 24, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 24, 24, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 24, 24, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 24, 24, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 24, 24, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 24, 24, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 24, 24, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 24, 24, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 24, 24, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 27, 27, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 12, 12, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 12, 12, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 12, 12, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 12, 12, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 12, 12, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 12, 12, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 12, 12, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 12, 12, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 12, 12, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 12, 12, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 12, 12, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 12, 12, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 12, 12, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 12, 12, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 12, 12, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 12, 12, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 12, 12, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 12, 12, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 12, 12, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 12, 12, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 13, 13, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 6, 6, 240)   2160        ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 6, 6, 240)   960         ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 6, 6, 240)   0           ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 6, 6, 240)    0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  conv_s1 (Conv2D)               (None, 6, 6, 240)    29040       ['block4a_se_excite[0][0]']
#
#  tbd-b1 (BatchNormalization)    (None, 6, 6, 240)    960         ['conv_s1[0][0]']
#
#  activation (Activation)        (None, 6, 6, 240)    0           ['tbd-b1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 240)         0           ['activation[0][0]']
#  alAveragePooling2D)
#
#  dense_s_1 (Dense)              (None, 180)          43380       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 50)           9050        ['dense_s_1[0][0]']
#
#  dense_output (Dense)           (None, 411)          20961       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 190,770
# Trainable params: 0
# Non-trainable params: 190,770
# __________________________________________________________________________________________________

# %%
# All layers are locked but running an epoch for demonstration purposes
model.compile(
    optimizer=Adam(1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    train_images,
    steps_per_epoch=len(train_images),
    validation_data=val_images,
    validation_steps=len(val_images),
    epochs=1,
)
# Out:
# 333/333 [==============================] - 91s 267ms/step - loss: 0.1289 - accuracy: 0.9628 - val_loss: 0.6113 - val_accuracy: 0.8715

# %%
# Now let's evaluate the test images against this checkpoint
results = model.evaluate(test_images, verbose=1)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# 104/104 [==============================] - 9s 82ms/step - loss: 0.7380 - accuracy: 0.8505
#     Test Loss: 0.73796
# Test Accuracy: 85.05%

# %%
# Let's now run predictions against the test images and show the output
# for a random subset as a grid
pred = model.predict(test_images)
pred = np.argmax(pred, axis=1)

# Map the label
labels = (test_images.class_indices)
labels = dict((v, k) for k, v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')

# Display 25 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_images.filepaths), 25)
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(25, 25), subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_images.filepaths[random_index[i]]))
    true_label = labels[test_images.classes[random_index[i]]]
    predicted_label = pred[random_index[i]]
    if true_label == predicted_label:
        color = "green"
    else:
        color = "red"
    ax.set_title(f"True: {true_label}\nPredicted: {predicted_label}", color=color)

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Classification report
y_test = [labels[idx] for idx in test_images.classes]
print(classification_report(y_test, pred))
# Out:
#                                precision    recall  f1-score   support
#
#               ABBOTTS BABBLER       0.66      0.76      0.70        33
#                 ABBOTTS BOOBY       0.54      0.53      0.54        36
#    ABYSSINIAN GROUND HORNBILL       0.85      0.92      0.88        36
#        AFRICAN EMERALD CUCKOO       0.77      0.65      0.70        31
#             AFRICAN FIREFINCH       0.73      0.81      0.77        27
#        AFRICAN OYSTER CATCHER       0.91      0.97      0.94        31
#         AFRICAN PIED HORNBILL       0.86      0.68      0.76        37
#                     ALBATROSS       0.82      0.69      0.75        26
#                ALBERTS TOWHEE       0.79      0.81      0.80        32
#          ALEXANDRINE PARAKEET       0.88      0.88      0.88        33
#                 ALPINE CHOUGH       0.86      0.97      0.91        33
#         ALTAMIRA YELLOWTHROAT       0.84      0.87      0.85        30
#               AMERICAN AVOCET       0.92      0.97      0.95        36
#              AMERICAN BITTERN       0.87      0.79      0.83        34
#                 AMERICAN COOT       0.84      0.84      0.84        32
#               AMERICAN DIPPER       0.92      0.85      0.88        39
#            AMERICAN GOLDFINCH       0.81      0.78      0.79        27
#              AMERICAN KESTREL       0.90      0.84      0.87        31
#                AMERICAN PIPIT       1.00      0.67      0.80        36
#             AMERICAN REDSTART       0.91      0.75      0.82        28
#                AMERICAN ROBIN       1.00      0.76      0.86        29
#               AMERICAN WIGEON       0.89      0.86      0.88        37
#             AMETHYST WOODSTAR       0.89      0.92      0.91        26
#                ANDEAN LAPWING       0.75      0.72      0.74        29
#           NORTHERN RED BISHOP       0.79      0.73      0.76        26
#             NORTHERN SHOVELER       0.93      0.90      0.92        31
#                       OILBIRD       0.93      0.78      0.85        36
#                  OKINAWA RAIL       0.74      0.97      0.84        32
#        ORANGE BREASTED TROGON       0.84      0.97      0.90        38
#        ORANGE BRESTED BUNTING       1.00      0.85      0.92        26
#                      OVENBIRD       0.98      0.87      0.92        47
#                OYSTER CATCHER       1.00      0.93      0.96        42
#               PAINTED BUNTING       0.91      0.88      0.89        33
#                        PALILA       0.96      0.81      0.88        32
#              PARADISE TANAGER       1.00      0.94      0.97        35
#              PARAKETT  AUKLET       0.91      0.97      0.94        31
#                   PARUS MAJOR       1.00      0.97      0.98        32
#       PATAGONIAN SIERRA FINCH       0.92      0.92      0.92        26
#                   PHAINOPEPLA       0.74      0.84      0.79        38
#                    PINK ROBIN       1.00      0.94      0.97        31
#             PLUSH CRESTED JAY       1.00      0.95      0.97        40
#               POMARINE JAEGER       0.48      0.50      0.49        28
#                        PUFFIN       0.92      1.00      0.96        33
#                     PUNA TEAL       0.77      0.81      0.79        37
#                  PURPLE FINCH       0.83      0.65      0.73        31
#              PURPLE GALLINULE       1.00      0.84      0.91        31
#                 PURPLE MARTIN       0.74      0.78      0.76        32
#                   PYRRHULOXIA       0.95      0.86      0.90        42
#                       QUETZAL       0.90      0.93      0.92        30
#              RAINBOW LORIKEET       0.90      0.96      0.93        28
#                     RAZORBILL       0.94      0.79      0.86        39
#         RED BEARDED BEE EATER       0.97      1.00      0.99        39
#             RED BELLIED PITTA       0.96      0.90      0.93        29
#         RED BILLED TROPICBIRD       0.79      0.79      0.79        43
#              RED BROWED FINCH       0.96      0.89      0.92        27
#                 RED CROSSBILL       1.00      0.71      0.83        38
#           RED FACED CORMORANT       0.79      0.71      0.75        31
#                      RED FODY       0.94      0.91      0.92        33
#               RED HEADED DUCK       0.93      0.88      0.90        32
#         RED HEADED WOODPECKER       0.80      0.89      0.84        27
#                      RED KNOT       0.79      0.78      0.78        40
#       RED LEGGED HONEYCREEPER       0.94      0.94      0.94        34
#              RED NAPED TROGON       0.78      0.91      0.84        32
#             RED TAILED THRUSH       1.00      0.96      0.98        26
#          RED WINGED BLACKBIRD       0.64      0.70      0.67        30
#           RED WISKERED BULBUL       1.00      1.00      1.00        32
#              REGENT BOWERBIRD       0.94      0.97      0.96        33
#                    ROADRUNNER       0.63      0.91      0.74        32
#                     ROCK DOVE       0.83      0.96      0.89        26
#        ROSE BREASTED COCKATOO       0.95      0.90      0.92        39
#        ROSE BREASTED GROSBEAK       0.94      0.91      0.93        35
#             ROSEATE SPOONBILL       0.97      0.92      0.95        39
#           ROSY FACED LOVEBIRD       0.96      0.93      0.95        28
#             ROUGH LEG BUZZARD       0.79      0.77      0.78        30
#                RUDDY SHELDUCK       0.91      0.94      0.93        33
#                  RUFOUS TREPE       0.91      0.96      0.94        53
#                 RUFUOS MOTMOT       0.97      0.89      0.93        38
#               SAMATRAN THRUSH       0.93      0.90      0.92        31
#                   SAND MARTIN       0.96      0.73      0.83        30
#                SATYR TRAGOPAN       0.87      1.00      0.93        34
#                   SAYS PHOEBE       0.84      0.79      0.82        39
#    SCARLET CROWNED FRUIT DOVE       0.90      0.87      0.89        31
#       SCARLET FACED LIOCICHLA       0.94      0.91      0.92        32
#                 SCARLET MACAW       0.89      1.00      0.94        31
#               SCARLET TANAGER       0.96      0.85      0.90        26
#                      SHOEBILL       0.83      0.83      0.83        35
#        SHORT BILLED DOWITCHER       0.83      0.58      0.68        33
#               SMITHS LONGSPUR       0.86      0.75      0.80        32
#                SNOW PARTRIDGE       0.58      0.74      0.65        35
#                  SNOWY PLOVER       1.00      0.54      0.70        26
#              SNOWY SHEATHBILL       0.81      0.81      0.81        37
#                          SORA       0.90      0.88      0.89        40
#              SPANGLED COTINGA       0.91      0.94      0.92        32
#         SPOON BILED SANDPIPER       0.77      0.59      0.67        29
#               SPOTTED CATBIRD       0.74      0.87      0.80        30
#        SPOTTED WHISTLING DUCK       0.76      0.78      0.77        37
#         SRI LANKA BLUE MAGPIE       0.97      1.00      0.98        32
#                  STEAMER DUCK       0.85      0.88      0.86        32
#             STRIATED CARACARA       0.89      0.82      0.85        39
#              STRIPPED MANAKIN       0.93      0.97      0.95        29
#                    SUNBITTERN       0.67      0.97      0.80        34
#               SUPERB STARLING       0.97      0.97      0.97        31
#                   SURF SCOTER       0.92      0.95      0.93        37
#                    TAILORBIRD       0.93      0.89      0.91        28
#                 TAIWAN MAGPIE       0.92      0.89      0.91        27
#                        TAKAHE       0.89      1.00      0.94        32
#               TAWNY FROGMOUTH       0.87      0.73      0.79        37
#                     TEAL DUCK       0.68      0.81      0.74        31
#                     TIT MOUSE       1.00      0.68      0.81        31
#                       TOUCHAN       0.96      0.96      0.96        27
#          TRICOLORED BLACKBIRD       0.59      0.79      0.68        28
#             TROPICAL KINGBIRD       0.82      0.87      0.84        31
#              TURQUOISE MOTMOT       0.93      0.84      0.88        31
#                 UMBRELLA BIRD       0.93      0.84      0.88        31
#                 VARIED THRUSH       1.00      0.90      0.95        39
#                         VEERY       0.89      0.82      0.85        38
#          VENEZUELIAN TROUPIAL       0.83      0.83      0.83        30
#                        VERDIN       0.88      0.83      0.86        36
#           VERMILION FLYCATHER       0.93      0.84      0.88        31
#       VICTORIA CROWNED PIGEON       0.90      0.93      0.92        30
#        VIOLET BACKED STARLING       0.87      0.85      0.86        40
#                 VIOLET CUCKOO       0.65      0.91      0.76        35
#                 VIOLET TURACO       0.91      0.97      0.94        32
#              VISAYAN HORNBILL       0.79      0.79      0.79        33
#                  WALL CREAPER       0.94      1.00      0.97        34
#               WATTLED LAPWING       0.89      0.86      0.87        28
#                      WHIMBREL       0.69      0.71      0.70        28
#            WHITE BROWED CRAKE       0.89      0.81      0.85        31
#          WHITE CHEEKED TURACO       0.79      0.84      0.81        31
#        WHITE CRESTED HORNBILL       0.96      0.72      0.82        32
#            WHITE NECKED RAVEN       0.65      0.88      0.75        32
#           WHITE TAILED TROPIC       0.68      0.71      0.69        35
#      WHITE THROATED BEE EATER       1.00      0.94      0.97        33
#              WILLOW PTARMIGAN       0.82      0.72      0.77        39
#      WILSONS BIRD OF PARADISE       0.83      0.94      0.88        31
#                     WOOD DUCK       0.88      0.98      0.92        43
#                   WOOD THRUSH       0.95      0.90      0.93        42
#   YELLOW BELLIED FLOWERPECKER       0.71      0.77      0.74        31
#          YELLOW BREASTED CHAT       0.97      0.93      0.95        40
#                YELLOW CACIQUE       0.92      0.77      0.84        31
#       YELLOW HEADED BLACKBIRD       1.00      0.94      0.97        32
#                    ZEBRA DOVE       0.70      0.97      0.81        34
#
#                      accuracy                           0.85     13292
#                     macro avg       0.86      0.85      0.85     13292
#                  weighted avg       0.86      0.85      0.85     13292

# %%
# https://keras.io/examples/vision/grad_cam/

def get_img_array(img_path, size):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=size)
    array = tf.keras.preprocessing.image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        inputs = model.inputs, outputs = [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]
    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = tf.keras.preprocessing.image.load_img(img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)
    # Save the superimposed image
    superimposed_img.save(cam_path)
    return cam_path

preprocess_input = tf.keras.applications.efficientnet.preprocess_input
decode_predictions = tf.keras.applications.efficientnet.decode_predictions

last_conv_layer_name = "conv_s1"
img_size = (96, 96, 3)

# Remove last layer's softmax
model.layers[-1].activation = None

# %%
# Let's now run predictions against the test images and show the output
# for a random subset as a grid
pred = model.predict(test_images)
pred = np.argmax(pred, axis=1)

# Map the label
labels = (test_images.class_indices)
labels = dict((v, k) for k, v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')

# Display 25 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_images.filepaths), 25)
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(25, 25), subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_images.filepaths[random_index[i]]))
    true_label = labels[test_images.classes[random_index[i]]]
    predicted_label = pred[random_index[i]]
    if true_label == predicted_label:
        color = "green"
    else:
        color = "red"
    ax.set_title(f"True: {true_label}\nPredicted: {predicted_label}", color=color)

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Display the part of the pictures used by the neural network to classify the pictures
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    img_path = test_images.filepaths[random_index[i]]
    img_array = tf.keras.applications.efficientnet.preprocess_input(get_img_array(img_path, size=img_size))
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
    cam_path = save_and_display_gradcam(img_path, heatmap)
    ax.imshow(plt.imread(cam_path))
    ax.set_title(f"True: {labels[test_images.classes[random_index[i]]]}\nPredicted: {pred[random_index[i]]}")
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Quantization
tflite_model_path = 'C:/colab/data/birds/bird_classifier_96x96_411.tflite'
test_extra_ds = "C:/colab/data/birds/test"


quantization_image_set = test_generator.flow_from_directory(
    directory=filtered_test_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True
)

def representative_dataset():
    i = 0
    for input_data, _ in quantization_image_set:
        yield [input_data]

        if i >= 6:
           break
        i += 1

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
converter.representative_dataset = representative_dataset

# Convert the model
tflite_model_int8 = converter.convert()

# Save the converted INT8 quantized model
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model_int8)
# Out:
# Found 13292 images belonging to 411 classes.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 29). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Osenin\AppData\Local\Temp\tmpihbnp5ob\assets
# INFO:tensorflow:Assets written to: C:\Users\Osenin\AppData\Local\Temp\tmpihbnp5ob\assets
# C:\Users\Osenin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "

# %%
# Using a smaller batch size
test_images = test_generator.flow_from_directory(
    directory=filtered_test_storage_ds,
    interpolation='bilinear',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)

tflite_interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

tflite_interpreter.resize_tensor_input(input_details[0]['index'], (32, 96, 96, 3))
tflite_interpreter.resize_tensor_input(output_details[0]['index'], (32, 5))
tflite_interpreter.allocate_tensors()

input_batch, _ = next(test_images)

results = []
average_accuracy = 0
for i in range(len(test_images)):
    batch = test_images[i]
    input_batch, labels = batch
    image_input_batch = tf.cast(input_batch, tf.int8)

    input_scale, input_zero_point = input_details[0]["quantization"]
    image_input_batch = tf.cast(image_input_batch, tf.float32)
    image_input_batch = (image_input_batch / input_scale) + input_zero_point
    image_input_batch = tf.cast(image_input_batch, tf.int8)
    if len(image_input_batch) == 32:
        tflite_interpreter.set_tensor(input_details[0]['index'], image_input_batch)
        tflite_interpreter.invoke()
        tflite_model_predictions = tflite_interpreter.get_tensor(output_details[0]['index'])

        tflite_predicted_ids = np.argmax(tflite_model_predictions, axis=-1)
        tflite_label_id = np.argmax(labels, axis=-1)

        correct_predictions = np.sum(tflite_predicted_ids == tflite_label_id)
        total_predictions = len(tflite_predicted_ids)
        accuracy_percentage = (correct_predictions / total_predictions) * 100

        results.append(accuracy_percentage)
        average_accuracy = sum(results) / len(results)
        print("\nIteration ", i, ": ", accuracy_percentage, " - Running Average: ", average_accuracy)

print("\nEnd Average: ", average_accuracy)
# Out:
# Found 13292 images belonging to 411 classes.
#
# Iteration  0 :  50.0  - Running Average:  50.0
#
# Iteration  1 :  46.875  - Running Average:  48.4375
#
# Iteration  2 :  71.875  - Running Average:  56.25
#
# Iteration  3 :  56.25  - Running Average:  56.25
#
# Iteration  4 :  81.25  - Running Average:  61.25
#
# Iteration  5 :  90.625  - Running Average:  66.14583333333333
#
# Iteration  6 :  68.75  - Running Average:  66.51785714285714
#
# Iteration  7 :  62.5  - Running Average:  66.015625
#
# Iteration  8 :  56.25  - Running Average:  64.93055555555556
#
# Iteration  9 :  78.125  - Running Average:  66.25
#
# Iteration  10 :  65.625  - Running Average:  66.19318181818181
#
# Iteration  11 :  81.25  - Running Average:  67.44791666666667
#
# Iteration  12 :  96.875  - Running Average:  69.71153846153847
#
# Iteration  13 :  68.75  - Running Average:  69.64285714285714
#
# Iteration  14 :  62.5  - Running Average:  69.16666666666667
#
# Iteration  15 :  40.625  - Running Average:  67.3828125
#
# Iteration  16 :  68.75  - Running Average:  67.46323529411765
#
# Iteration  17 :  81.25  - Running Average:  68.22916666666667
#
# Iteration  18 :  71.875  - Running Average:  68.42105263157895
#
# Iteration  19 :  68.75  - Running Average:  68.4375
#
# Iteration  20 :  78.125  - Running Average:  68.89880952380952
#
# Iteration  21 :  62.5  - Running Average:  68.60795454545455
#
# Iteration  22 :  84.375  - Running Average:  69.29347826086956
#
# Iteration  23 :  62.5  - Running Average:  69.01041666666667
#
# Iteration  24 :  68.75  - Running Average:  69.0
#
# Iteration  25 :  81.25  - Running Average:  69.47115384615384
#
# Iteration  26 :  62.5  - Running Average:  69.21296296296296
#
# Iteration  27 :  75.0  - Running Average:  69.41964285714286
#
# Iteration  28 :  68.75  - Running Average:  69.39655172413794
#
# Iteration  29 :  65.625  - Running Average:  69.27083333333333
#
# Iteration  30 :  75.0  - Running Average:  69.45564516129032
#
# Iteration  31 :  71.875  - Running Average:  69.53125
#
# Iteration  32 :  21.875  - Running Average:  68.08712121212122
#
# Iteration  33 :  62.5  - Running Average:  67.92279411764706
#
# Iteration  34 :  71.875  - Running Average:  68.03571428571429
#
# Iteration  35 :  90.625  - Running Average:  68.66319444444444
#
# Iteration  36 :  37.5  - Running Average:  67.82094594594595
#
# Iteration  37 :  56.25  - Running Average:  67.51644736842105
#
# Iteration  38 :  87.5  - Running Average:  68.02884615384616
#
# Iteration  39 :  78.125  - Running Average:  68.28125
#
# Iteration  40 :  75.0  - Running Average:  68.4451219512195
#
# Iteration  41 :  78.125  - Running Average:  68.67559523809524
#
# Iteration  42 :  68.75  - Running Average:  68.67732558139535
#
# Iteration  43 :  65.625  - Running Average:  68.60795454545455
#
# Iteration  44 :  68.75  - Running Average:  68.61111111111111
#
# Iteration  45 :  81.25  - Running Average:  68.88586956521739
#
# Iteration  46 :  87.5  - Running Average:  69.28191489361703
#
# Iteration  47 :  59.375  - Running Average:  69.07552083333333
#
# Iteration  48 :  59.375  - Running Average:  68.87755102040816
#
# Iteration  49 :  90.625  - Running Average:  69.3125
#
# Iteration  50 :  90.625  - Running Average:  69.73039215686275
#
# Iteration  51 :  96.875  - Running Average:  70.25240384615384
#
# Iteration  52 :  84.375  - Running Average:  70.51886792452831
#
# Iteration  53 :  84.375  - Running Average:  70.77546296296296
#
# Iteration  54 :  65.625  - Running Average:  70.68181818181819
#
# Iteration  55 :  87.5  - Running Average:  70.98214285714286
#
# Iteration  56 :  90.625  - Running Average:  71.32675438596492
#
# Iteration  57 :  87.5  - Running Average:  71.60560344827586
#
# Iteration  58 :  71.875  - Running Average:  71.61016949152543
#
# Iteration  59 :  84.375  - Running Average:  71.82291666666667
#
# Iteration  60 :  93.75  - Running Average:  72.18237704918033
#
# Iteration  61 :  65.625  - Running Average:  72.07661290322581
#
# Iteration  62 :  43.75  - Running Average:  71.62698412698413
#
# Iteration  63 :  81.25  - Running Average:  71.77734375
#
# Iteration  64 :  71.875  - Running Average:  71.77884615384616
#
# Iteration  65 :  87.5  - Running Average:  72.01704545454545
#
# Iteration  66 :  71.875  - Running Average:  72.01492537313433
#
# Iteration  67 :  75.0  - Running Average:  72.05882352941177
#
# Iteration  68 :  90.625  - Running Average:  72.32789855072464
#
# Iteration  69 :  90.625  - Running Average:  72.58928571428571
#
# Iteration  70 :  71.875  - Running Average:  72.57922535211267
#
# Iteration  71 :  65.625  - Running Average:  72.48263888888889
#
# Iteration  72 :  87.5  - Running Average:  72.68835616438356
#
# Iteration  73 :  87.5  - Running Average:  72.88851351351352
#
# Iteration  74 :  71.875  - Running Average:  72.875
#
# Iteration  75 :  81.25  - Running Average:  72.98519736842105
#
# Iteration  76 :  84.375  - Running Average:  73.13311688311688
#
# Iteration  77 :  81.25  - Running Average:  73.23717948717949
#
# Iteration  78 :  84.375  - Running Average:  73.37816455696202
#
# Iteration  79 :  87.5  - Running Average:  73.5546875
#
# Iteration  80 :  62.5  - Running Average:  73.41820987654322
#
# Iteration  81 :  68.75  - Running Average:  73.36128048780488
#
# Iteration  82 :  71.875  - Running Average:  73.3433734939759
#
# Iteration  83 :  62.5  - Running Average:  73.21428571428571
#
# Iteration  84 :  81.25  - Running Average:  73.30882352941177
#
# Iteration  85 :  65.625  - Running Average:  73.21947674418605
#
# Iteration  86 :  81.25  - Running Average:  73.3117816091954
#
# Iteration  87 :  53.125  - Running Average:  73.08238636363636
#
# Iteration  88 :  46.875  - Running Average:  72.78792134831461
#
# Iteration  89 :  37.5  - Running Average:  72.39583333333333
#
# Iteration  90 :  46.875  - Running Average:  72.11538461538461
#
# Iteration  91 :  59.375  - Running Average:  71.97690217391305
#
# Iteration  92 :  59.375  - Running Average:  71.84139784946237
#
# Iteration  93 :  93.75  - Running Average:  72.07446808510639
#
# Iteration  94 :  78.125  - Running Average:  72.13815789473684
#
# Iteration  95 :  78.125  - Running Average:  72.20052083333333
#
# Iteration  96 :  59.375  - Running Average:  72.06829896907216
#
# Iteration  97 :  78.125  - Running Average:  72.13010204081633
#
# Iteration  98 :  53.125  - Running Average:  71.93813131313131
#
# Iteration  99 :  90.625  - Running Average:  72.125
#
# Iteration  100 :  93.75  - Running Average:  72.33910891089108
#
# Iteration  101 :  68.75  - Running Average:  72.30392156862744
#
# Iteration  102 :  75.0  - Running Average:  72.33009708737865
#
# Iteration  103 :  87.5  - Running Average:  72.47596153846153
#
# Iteration  104 :  90.625  - Running Average:  72.64880952380952
#
# Iteration  105 :  87.5  - Running Average:  72.78891509433963
#
# Iteration  106 :  93.75  - Running Average:  72.98481308411215
#
# Iteration  107 :  100.0  - Running Average:  73.23495370370371
#
# Iteration  108 :  90.625  - Running Average:  73.39449541284404
#
# Iteration  109 :  84.375  - Running Average:  73.49431818181819
#
# Iteration  110 :  87.5  - Running Average:  73.62049549549549
#
# Iteration  111 :  56.25  - Running Average:  73.46540178571429
#
# Iteration  112 :  75.0  - Running Average:  73.47898230088495
#
# Iteration  113 :  87.5  - Running Average:  73.60197368421052
#
# Iteration  114 :  65.625  - Running Average:  73.53260869565217
#
# Iteration  115 :  78.125  - Running Average:  73.57219827586206
#
# Iteration  116 :  56.25  - Running Average:  73.4241452991453
#
# Iteration  117 :  87.5  - Running Average:  73.54343220338983
#
# Iteration  118 :  65.625  - Running Average:  73.47689075630252
#
# Iteration  119 :  75.0  - Running Average:  73.48958333333333
#
# Iteration  120 :  71.875  - Running Average:  73.47623966942149
#
# Iteration  121 :  75.0  - Running Average:  73.48872950819673
#
# Iteration  122 :  78.125  - Running Average:  73.52642276422765
#
# Iteration  123 :  90.625  - Running Average:  73.66431451612904
#
# Iteration  124 :  84.375  - Running Average:  73.75
#
# Iteration  125 :  90.625  - Running Average:  73.88392857142857
#
# Iteration  126 :  62.5  - Running Average:  73.79429133858268
#
# Iteration  127 :  75.0  - Running Average:  73.8037109375
#
# Iteration  128 :  56.25  - Running Average:  73.66763565891473
#
# Iteration  129 :  59.375  - Running Average:  73.5576923076923
#
# Iteration  130 :  78.125  - Running Average:  73.5925572519084
#
# Iteration  131 :  78.125  - Running Average:  73.62689393939394
#
# Iteration  132 :  78.125  - Running Average:  73.66071428571429
#
# Iteration  133 :  84.375  - Running Average:  73.74067164179104
#
# Iteration  134 :  75.0  - Running Average:  73.75
#
# Iteration  135 :  78.125  - Running Average:  73.78216911764706
#
# Iteration  136 :  75.0  - Running Average:  73.79105839416059
#
# Iteration  137 :  68.75  - Running Average:  73.75452898550725
#
# Iteration  138 :  84.375  - Running Average:  73.83093525179856
#
# Iteration  139 :  71.875  - Running Average:  73.81696428571429
#
# Iteration  140 :  87.5  - Running Average:  73.91400709219859
#
# Iteration  141 :  50.0  - Running Average:  73.7455985915493
#
# Iteration  142 :  65.625  - Running Average:  73.68881118881119
#
# Iteration  143 :  87.5  - Running Average:  73.78472222222223
#
# Iteration  144 :  75.0  - Running Average:  73.79310344827586
#
# Iteration  145 :  100.0  - Running Average:  73.97260273972603
#
# Iteration  146 :  53.125  - Running Average:  73.83078231292517
#
# Iteration  147 :  59.375  - Running Average:  73.73310810810811
#
# Iteration  148 :  93.75  - Running Average:  73.86744966442953
#
# Iteration  149 :  93.75  - Running Average:  74.0
#
# Iteration  150 :  87.5  - Running Average:  74.08940397350993
#
# Iteration  151 :  90.625  - Running Average:  74.19819078947368
#
# Iteration  152 :  65.625  - Running Average:  74.1421568627451
#
# Iteration  153 :  65.625  - Running Average:  74.08685064935065
#
# Iteration  154 :  65.625  - Running Average:  74.03225806451613
#
# Iteration  155 :  75.0  - Running Average:  74.03846153846153
#
# Iteration  156 :  62.5  - Running Average:  73.96496815286625
#
# Iteration  157 :  84.375  - Running Average:  74.03085443037975
#
# Iteration  158 :  65.625  - Running Average:  73.97798742138365
#
# Iteration  159 :  84.375  - Running Average:  74.04296875
#
# Iteration  160 :  78.125  - Running Average:  74.06832298136646
#
# Iteration  161 :  78.125  - Running Average:  74.09336419753086
#
# Iteration  162 :  87.5  - Running Average:  74.17561349693251
#
# Iteration  163 :  68.75  - Running Average:  74.14253048780488
#
# Iteration  164 :  81.25  - Running Average:  74.18560606060606
#
# Iteration  165 :  87.5  - Running Average:  74.26581325301204
#
# Iteration  166 :  78.125  - Running Average:  74.28892215568862
#
# Iteration  167 :  81.25  - Running Average:  74.33035714285714
#
# Iteration  168 :  71.875  - Running Average:  74.31582840236686
#
# Iteration  169 :  93.75  - Running Average:  74.43014705882354
#
# Iteration  170 :  81.25  - Running Average:  74.47002923976608
#
# Iteration  171 :  75.0  - Running Average:  74.47311046511628
#
# Iteration  172 :  93.75  - Running Average:  74.58453757225433
#
# Iteration  173 :  84.375  - Running Average:  74.64080459770115
#
# Iteration  174 :  81.25  - Running Average:  74.67857142857143
#
# Iteration  175 :  84.375  - Running Average:  74.73366477272727
#
# Iteration  176 :  84.375  - Running Average:  74.78813559322033
#
# Iteration  177 :  90.625  - Running Average:  74.87710674157303
#
# Iteration  178 :  81.25  - Running Average:  74.9127094972067
#
# Iteration  179 :  87.5  - Running Average:  74.98263888888889
#
# Iteration  180 :  68.75  - Running Average:  74.9482044198895
#
# Iteration  181 :  65.625  - Running Average:  74.89697802197803
#
# Iteration  182 :  78.125  - Running Average:  74.9146174863388
#
# Iteration  183 :  65.625  - Running Average:  74.86413043478261
#
# Iteration  184 :  65.625  - Running Average:  74.8141891891892
#
# Iteration  185 :  78.125  - Running Average:  74.83198924731182
#
# Iteration  186 :  68.75  - Running Average:  74.79946524064171
#
# Iteration  187 :  59.375  - Running Average:  74.71742021276596
#
# Iteration  188 :  81.25  - Running Average:  74.75198412698413
#
# Iteration  189 :  78.125  - Running Average:  74.76973684210526
#
# Iteration  190 :  90.625  - Running Average:  74.85274869109948
#
# Iteration  191 :  81.25  - Running Average:  74.88606770833333
#
# Iteration  192 :  46.875  - Running Average:  74.74093264248705
#
# Iteration  193 :  75.0  - Running Average:  74.74226804123711
#
# Iteration  194 :  78.125  - Running Average:  74.75961538461539
#
# Iteration  195 :  87.5  - Running Average:  74.82461734693878
#
# Iteration  196 :  87.5  - Running Average:  74.88895939086295
#
# Iteration  197 :  78.125  - Running Average:  74.90530303030303
#
# Iteration  198 :  78.125  - Running Average:  74.9214824120603
#
# Iteration  199 :  68.75  - Running Average:  74.890625
#
# Iteration  200 :  53.125  - Running Average:  74.78233830845771
#
# Iteration  201 :  62.5  - Running Average:  74.72153465346534
#
# Iteration  202 :  87.5  - Running Average:  74.78448275862068
#
# Iteration  203 :  90.625  - Running Average:  74.86213235294117
#
# Iteration  204 :  87.5  - Running Average:  74.92378048780488
#
# Iteration  205 :  53.125  - Running Average:  74.81796116504854
#
# Iteration  206 :  43.75  - Running Average:  74.66787439613526
#
# Iteration  207 :  31.25  - Running Average:  74.45913461538461
#
# Iteration  208 :  46.875  - Running Average:  74.32715311004785
#
# Iteration  209 :  81.25  - Running Average:  74.36011904761905
#
# Iteration  210 :  90.625  - Running Average:  74.43720379146919
#
# Iteration  211 :  81.25  - Running Average:  74.46933962264151
#
# Iteration  212 :  96.875  - Running Average:  74.57453051643192
#
# Iteration  213 :  71.875  - Running Average:  74.56191588785046
#
# Iteration  214 :  65.625  - Running Average:  74.5203488372093
#
# Iteration  215 :  75.0  - Running Average:  74.52256944444444
#
# Iteration  216 :  78.125  - Running Average:  74.53917050691244
#
# Iteration  217 :  71.875  - Running Average:  74.52694954128441
#
# Iteration  218 :  84.375  - Running Average:  74.57191780821918
#
# Iteration  219 :  68.75  - Running Average:  74.54545454545455
#
# Iteration  220 :  62.5  - Running Average:  74.49095022624434
#
# Iteration  221 :  71.875  - Running Average:  74.47916666666667
#
# Iteration  222 :  81.25  - Running Average:  74.50952914798206
#
# Iteration  223 :  87.5  - Running Average:  74.56752232142857
#
# Iteration  224 :  75.0  - Running Average:  74.56944444444444
#
# Iteration  225 :  90.625  - Running Average:  74.64048672566372
#
# Iteration  226 :  100.0  - Running Average:  74.75220264317181
#
# Iteration  227 :  90.625  - Running Average:  74.8218201754386
#
# Iteration  228 :  81.25  - Running Average:  74.84989082969432
#
# Iteration  229 :  75.0  - Running Average:  74.85054347826087
#
# Iteration  230 :  59.375  - Running Average:  74.78354978354979
#
# Iteration  231 :  78.125  - Running Average:  74.79795258620689
#
# Iteration  232 :  87.5  - Running Average:  74.8524678111588
#
# Iteration  233 :  81.25  - Running Average:  74.8798076923077
#
# Iteration  234 :  53.125  - Running Average:  74.7872340425532
#
# Iteration  235 :  81.25  - Running Average:  74.81461864406779
#
# Iteration  236 :  90.625  - Running Average:  74.88132911392405
#
# Iteration  237 :  59.375  - Running Average:  74.81617647058823
#
# Iteration  238 :  71.875  - Running Average:  74.80387029288703
#
# Iteration  239 :  87.5  - Running Average:  74.85677083333333
#
# Iteration  240 :  93.75  - Running Average:  74.93516597510373
#
# Iteration  241 :  90.625  - Running Average:  75.0
#
# Iteration  242 :  71.875  - Running Average:  74.98713991769547
#
# Iteration  243 :  56.25  - Running Average:  74.91034836065573
#
# Iteration  244 :  65.625  - Running Average:  74.87244897959184
#
# Iteration  245 :  53.125  - Running Average:  74.78404471544715
#
# Iteration  246 :  65.625  - Running Average:  74.74696356275304
#
# Iteration  247 :  87.5  - Running Average:  74.79838709677419
#
# Iteration  248 :  96.875  - Running Average:  74.88704819277109
#
# Iteration  249 :  40.625  - Running Average:  74.75
#
# Iteration  250 :  71.875  - Running Average:  74.73854581673307
#
# Iteration  251 :  96.875  - Running Average:  74.82638888888889
#
# Iteration  252 :  90.625  - Running Average:  74.88883399209486
#
# Iteration  253 :  87.5  - Running Average:  74.9384842519685
#
# Iteration  254 :  84.375  - Running Average:  74.97549019607843
#
# Iteration  255 :  90.625  - Running Average:  75.03662109375
#
# Iteration  256 :  84.375  - Running Average:  75.07295719844358
#
# Iteration  257 :  81.25  - Running Average:  75.09689922480621
#
# Iteration  258 :  87.5  - Running Average:  75.14478764478764
#
# Iteration  259 :  81.25  - Running Average:  75.16826923076923
#
# Iteration  260 :  78.125  - Running Average:  75.17959770114942
#
# Iteration  261 :  68.75  - Running Average:  75.1550572519084
#
# Iteration  262 :  71.875  - Running Average:  75.1425855513308
#
# Iteration  263 :  56.25  - Running Average:  75.07102272727273
#
# Iteration  264 :  84.375  - Running Average:  75.10613207547169
#
# Iteration  265 :  65.625  - Running Average:  75.07048872180451
#
# Iteration  266 :  56.25  - Running Average:  75.0
#
# Iteration  267 :  81.25  - Running Average:  75.02332089552239
#
# Iteration  268 :  65.625  - Running Average:  74.98838289962825
#
# Iteration  269 :  71.875  - Running Average:  74.97685185185185
#
# Iteration  270 :  78.125  - Running Average:  74.98846863468634
#
# Iteration  271 :  78.125  - Running Average:  75.0
#
# Iteration  272 :  65.625  - Running Average:  74.96565934065934
#
# Iteration  273 :  84.375  - Running Average:  75.0
#
# Iteration  274 :  65.625  - Running Average:  74.9659090909091
#
# Iteration  275 :  59.375  - Running Average:  74.90942028985508
#
# Iteration  276 :  59.375  - Running Average:  74.8533393501805
#
# Iteration  277 :  43.75  - Running Average:  74.74145683453237
#
# Iteration  278 :  50.0  - Running Average:  74.65277777777777
#
# Iteration  279 :  50.0  - Running Average:  74.56473214285714
#
# Iteration  280 :  90.625  - Running Average:  74.62188612099644
#
# Iteration  281 :  53.125  - Running Average:  74.5456560283688
#
# Iteration  282 :  71.875  - Running Average:  74.53621908127208
#
# Iteration  283 :  93.75  - Running Average:  74.60387323943662
#
# Iteration  284 :  56.25  - Running Average:  74.53947368421052
#
# Iteration  285 :  6.25  - Running Average:  74.3006993006993
#
# Iteration  286 :  90.625  - Running Average:  74.35757839721255
#
# Iteration  287 :  50.0  - Running Average:  74.27300347222223
#
# Iteration  288 :  40.625  - Running Average:  74.15657439446366
#
# Iteration  289 :  50.0  - Running Average:  74.07327586206897
#
# Iteration  290 :  78.125  - Running Average:  74.08719931271477
#
# Iteration  291 :  71.875  - Running Average:  74.07962328767124
#
# Iteration  292 :  75.0  - Running Average:  74.08276450511946
#
# Iteration  293 :  75.0  - Running Average:  74.08588435374149
#
# Iteration  294 :  87.5  - Running Average:  74.13135593220339
#
# Iteration  295 :  71.875  - Running Average:  74.12373310810811
#
# Iteration  296 :  93.75  - Running Average:  74.18981481481481
#
# Iteration  297 :  96.875  - Running Average:  74.26593959731544
#
# Iteration  298 :  71.875  - Running Average:  74.25794314381271
#
# Iteration  299 :  65.625  - Running Average:  74.22916666666667
#
# Iteration  300 :  84.375  - Running Average:  74.26287375415282
#
# Iteration  301 :  90.625  - Running Average:  74.31705298013244
#
# Iteration  302 :  75.0  - Running Average:  74.31930693069307
#
# Iteration  303 :  81.25  - Running Average:  74.34210526315789
#
# Iteration  304 :  84.375  - Running Average:  74.375
#
# Iteration  305 :  71.875  - Running Average:  74.36683006535948
#
# Iteration  306 :  78.125  - Running Average:  74.37907166123779
#
# Iteration  307 :  78.125  - Running Average:  74.39123376623377
#
# Iteration  308 :  62.5  - Running Average:  74.35275080906149
#
# Iteration  309 :  75.0  - Running Average:  74.35483870967742
#
# Iteration  310 :  50.0  - Running Average:  74.27652733118971
#
# Iteration  311 :  59.375  - Running Average:  74.22876602564102
#
# Iteration  312 :  87.5  - Running Average:  74.27116613418531
#
# Iteration  313 :  56.25  - Running Average:  74.21377388535032
#
# Iteration  314 :  43.75  - Running Average:  74.1170634920635
#
# Iteration  315 :  65.625  - Running Average:  74.09018987341773
#
# Iteration  316 :  46.875  - Running Average:  74.00433753943217
#
# Iteration  317 :  75.0  - Running Average:  74.00746855345912
#
# Iteration  318 :  81.25  - Running Average:  74.03017241379311
#
# Iteration  319 :  93.75  - Running Average:  74.091796875
#
# Iteration  320 :  50.0  - Running Average:  74.01674454828661
#
# Iteration  321 :  84.375  - Running Average:  74.04891304347827
#
# Iteration  322 :  93.75  - Running Average:  74.10990712074303
#
# Iteration  323 :  68.75  - Running Average:  74.09336419753086
#
# Iteration  324 :  71.875  - Running Average:  74.08653846153847
#
# Iteration  325 :  71.875  - Running Average:  74.079754601227
#
# Iteration  326 :  65.625  - Running Average:  74.0538990825688
#
# Iteration  327 :  68.75  - Running Average:  74.03772865853658
#
# Iteration  328 :  62.5  - Running Average:  74.00265957446808
#
# Iteration  329 :  78.125  - Running Average:  74.01515151515152
#
# Iteration  330 :  71.875  - Running Average:  74.00868580060423
#
# Iteration  331 :  62.5  - Running Average:  73.97402108433735
#
# Iteration  332 :  84.375  - Running Average:  74.00525525525525
#
# Iteration  333 :  87.5  - Running Average:  74.04565868263474
#
# Iteration  334 :  71.875  - Running Average:  74.03917910447761
#
# Iteration  335 :  71.875  - Running Average:  74.0327380952381
#
# Iteration  336 :  87.5  - Running Average:  74.0727002967359
#
# Iteration  337 :  87.5  - Running Average:  74.11242603550296
#
# Iteration  338 :  78.125  - Running Average:  74.12426253687316
#
# Iteration  339 :  71.875  - Running Average:  74.11764705882354
#
# Iteration  340 :  87.5  - Running Average:  74.15689149560117
#
# Iteration  341 :  71.875  - Running Average:  74.15021929824562
#
# Iteration  342 :  87.5  - Running Average:  74.18913994169097
#
# Iteration  343 :  68.75  - Running Average:  74.17332848837209
#
# Iteration  344 :  59.375  - Running Average:  74.1304347826087
#
# Iteration  345 :  84.375  - Running Average:  74.16004335260115
#
# Iteration  346 :  75.0  - Running Average:  74.16246397694525
#
# Iteration  347 :  71.875  - Running Average:  74.1558908045977
#
# Iteration  348 :  78.125  - Running Average:  74.16726361031519
#
# Iteration  349 :  65.625  - Running Average:  74.14285714285714
#
# Iteration  350 :  62.5  - Running Average:  74.1096866096866
#
# Iteration  351 :  78.125  - Running Average:  74.12109375
#
# Iteration  352 :  62.5  - Running Average:  74.08817280453258
#
# Iteration  353 :  75.0  - Running Average:  74.09074858757062
#
# Iteration  354 :  87.5  - Running Average:  74.12852112676056
#
# Iteration  355 :  81.25  - Running Average:  74.14852528089888
#
# Iteration  356 :  78.125  - Running Average:  74.15966386554622
#
# Iteration  357 :  81.25  - Running Average:  74.17946927374301
#
# Iteration  358 :  56.25  - Running Average:  74.12952646239555
#
# Iteration  359 :  50.0  - Running Average:  74.0625
#
# Iteration  360 :  46.875  - Running Average:  73.98718836565097
#
# Iteration  361 :  62.5  - Running Average:  73.95545580110497
#
# Iteration  362 :  68.75  - Running Average:  73.94111570247934
#
# Iteration  363 :  81.25  - Running Average:  73.96119505494505
#
# Iteration  364 :  75.0  - Running Average:  73.96404109589041
#
# Iteration  365 :  37.5  - Running Average:  73.86441256830601
#
# Iteration  366 :  65.625  - Running Average:  73.84196185286103
#
# Iteration  367 :  65.625  - Running Average:  73.8196331521739
#
# Iteration  368 :  93.75  - Running Average:  73.87364498644986
#
# Iteration  369 :  68.75  - Running Average:  73.85979729729729
#
# Iteration  370 :  81.25  - Running Average:  73.87971698113208
#
# Iteration  371 :  90.625  - Running Average:  73.9247311827957
#
# Iteration  372 :  81.25  - Running Average:  73.94436997319035
#
# Iteration  373 :  87.5  - Running Average:  73.98061497326204
#
# Iteration  374 :  81.25  - Running Average:  74.0
#
# Iteration  375 :  81.25  - Running Average:  74.01928191489361
#
# Iteration  376 :  81.25  - Running Average:  74.03846153846153
#
# Iteration  377 :  78.125  - Running Average:  74.04927248677248
#
# Iteration  378 :  65.625  - Running Average:  74.02704485488127
#
# Iteration  379 :  78.125  - Running Average:  74.03782894736842
#
# Iteration  380 :  62.5  - Running Average:  74.00754593175853
#
# Iteration  381 :  75.0  - Running Average:  74.01014397905759
#
# Iteration  382 :  75.0  - Running Average:  74.01272845953002
#
# Iteration  383 :  68.75  - Running Average:  73.9990234375
#
# Iteration  384 :  81.25  - Running Average:  74.01785714285714
#
# Iteration  385 :  75.0  - Running Average:  74.02040155440415
#
# Iteration  386 :  93.75  - Running Average:  74.07138242894057
#
# Iteration  387 :  68.75  - Running Average:  74.0576675257732
#
# Iteration  388 :  81.25  - Running Average:  74.07615681233933
#
# Iteration  389 :  78.125  - Running Average:  74.08653846153847
#
# Iteration  390 :  84.375  - Running Average:  74.1128516624041
#
# Iteration  391 :  81.25  - Running Average:  74.13105867346938
#
# Iteration  392 :  75.0  - Running Average:  74.13326972010178
#
# Iteration  393 :  84.375  - Running Average:  74.15926395939087
#
# Iteration  394 :  78.125  - Running Average:  74.16930379746836
#
# Iteration  395 :  68.75  - Running Average:  74.15561868686869
#
# Iteration  396 :  81.25  - Running Average:  74.1734886649874
#
# Iteration  397 :  81.25  - Running Average:  74.1912688442211
#
# Iteration  398 :  75.0  - Running Average:  74.19329573934837
#
# Iteration  399 :  62.5  - Running Average:  74.1640625
#
# Iteration  400 :  78.125  - Running Average:  74.17394014962593
#
# Iteration  401 :  59.375  - Running Average:  74.13712686567165
#
# Iteration  402 :  65.625  - Running Average:  74.11600496277916
#
# Iteration  403 :  50.0  - Running Average:  74.05631188118812
#
# Iteration  404 :  71.875  - Running Average:  74.05092592592592
#
# Iteration  405 :  75.0  - Running Average:  74.05326354679804
#
# Iteration  406 :  59.375  - Running Average:  74.01719901719902
#
# Iteration  407 :  87.5  - Running Average:  74.05024509803921
#
# Iteration  408 :  100.0  - Running Average:  74.11369193154034
#
# Iteration  409 :  81.25  - Running Average:  74.1310975609756
#
# Iteration  410 :  46.875  - Running Average:  74.06478102189782
#
# Iteration  411 :  90.625  - Running Average:  74.10497572815534
#
# Iteration  412 :  68.75  - Running Average:  74.09200968523002
#
# Iteration  413 :  84.375  - Running Average:  74.11684782608695
#
# Iteration  414 :  93.75  - Running Average:  74.16415662650603
#
# End Average:  74.16415662650603
