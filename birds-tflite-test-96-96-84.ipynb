# %%
import tensorflow as tf
from pathlib import Path
import os
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from helper_functions import walk_through_dir

BATCH_SIZE = 32
TARGET_SIZE = (96, 96)

def should_ignore(path, ignored_paths):
    return any(ignored_path in path for ignored_path in ignored_paths)

ignored_paths = ['LOONEY BIRDS', 'TURKEY', 'PENGUIN', 'OWL', 'EAGLE', 'EMU',
                 'VULTURE', 'CHICKEN', 'GOOSE', 'OSTRICH', 'CONDOR', 'PELICAN',
                'CASSOWARY', 'FLAMINGO', "CRANE", "SWAN", "PEACOCK", "IBIS",
                 "STORK", "PHEASANT", "FALCON", "OSPREY", "HAWK", "CURASSOW",
                 "VULTURINE", "HEN", "HUMMINGBIRD", "SWALLOW", "WARBLER", "FLYCATCHER",
                 "KINGFISHER", "HERON", "EGRET", "KINGLET", "SHRIKE", "WREN", "ABBOTTS BOOBY"]


dataset = "C:/colab/data/birds/train"
walk_through_dir(dataset);
image_dir = Path(dataset)
filepaths = [str(path) for path in image_dir.glob('**/*') if path.is_file() and not should_ignore(str(path), ignored_paths)]
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
train_df = pd.concat([filepaths, labels], axis=1)

dataset = "C:/colab/data/birds/test"
walk_through_dir(dataset);
image_dir = Path(dataset)
filepaths = [str(path) for path in image_dir.glob('**/*') if path.is_file() and not should_ignore(str(path), ignored_paths)]
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
test_df = pd.concat([filepaths, labels], axis=1)

dataset = "C:/colab/data/birds/valid"
walk_through_dir(dataset);
image_dir = Path(dataset)
filepaths = [str(path) for path in image_dir.glob('**/*') if path.is_file() and not should_ignore(str(path), ignored_paths)]
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
valid_df = pd.concat([filepaths, labels], axis=1)

train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    validation_split=0.2,
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
)

test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    interpolation='lanczos',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
)

val_images = test_generator.flow_from_dataframe(
    dataframe=valid_df,
    x_col='Filepath',
    y_col='Label',
    interpolation='lanczos',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    interpolation='lanczos',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# There are 525 directories and 0 images in 'C:/colab/data/birds/train'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\ABBOTTS BABBLER'.
# There are 0 directories and 180 images in 'C:/colab/data/birds/train\ABBOTTS BOOBY'.
# There are 0 directories and 179 images in 'C:/colab/data/birds/train\ABYSSINIAN GROUND HORNBILL'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\AFRICAN CROWNED CRANE'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\AFRICAN EMERALD CUCKOO'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\AFRICAN FIREFINCH'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\AFRICAN OYSTER CATCHER'.
# There are 0 directories and 187 images in 'C:/colab/data/birds/train\AFRICAN PIED HORNBILL'.
# There are 0 directories and 179 images in 'C:/colab/data/birds/train\AFRICAN PYGMY GOOSE'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\ALBATROSS'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\ALBERTS TOWHEE'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\ALEXANDRINE PARAKEET'.
# There are 0 directories and 166 images in 'C:/colab/data/birds/train\ALPINE CHOUGH'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\ALTAMIRA YELLOWTHROAT'.
# There are 0 directories and 179 images in 'C:/colab/data/birds/train\AMERICAN AVOCET'.
# There are 0 directories and 170 images in 'C:/colab/data/birds/train\AMERICAN BITTERN'.
# There are 0 directories and 158 images in 'C:/colab/data/birds/train\AMERICAN COOT'.
# There are 0 directories and 193 images in 'C:/colab/data/birds/train\AMERICAN DIPPER'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\AMERICAN FLAMINGO'.
# There are 0 directories and 133 images in 'C:/colab/data/birds/train\AMERICAN GOLDFINCH'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\AMERICAN KESTREL'.
# There are 0 directories and 179 images in 'C:/colab/data/birds/train\AMERICAN PIPIT'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\AMERICAN REDSTART'.
# There are 0 directories and 147 images in 'C:/colab/data/birds/train\AMERICAN ROBIN'.
# There are 0 directories and 187 images in 'C:/colab/data/birds/train\AMERICAN WIGEON'.
# There are 0 directories and 130 images in 'C:/colab/data/birds/train\AMETHYST WOODSTAR'.
# There are 0 directories and 134 images in 'C:/colab/data/birds/train\ANDEAN GOOSE'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\ANDEAN LAPWING'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\ANDEAN SISKIN'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\ANHINGA'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\ANIANIAU'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\ANNAS HUMMINGBIRD'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\ANTBIRD'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\ANTILLEAN EUPHONIA'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\APAPANE'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\APOSTLEBIRD'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\ARARIPE MANAKIN'.
# There are 0 directories and 188 images in 'C:/colab/data/birds/train\ASHY STORM PETREL'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\ASHY THRUSHBIRD'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\ASIAN CRESTED IBIS'.
# There are 0 directories and 141 images in 'C:/colab/data/birds/train\ASIAN DOLLARD BIRD'.
# There are 0 directories and 220 images in 'C:/colab/data/birds/train\ASIAN GREEN BEE EATER'.
# There are 0 directories and 190 images in 'C:/colab/data/birds/train\ASIAN OPENBILL STORK'.
# There are 0 directories and 187 images in 'C:/colab/data/birds/train\AUCKLAND SHAQ'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\AUSTRAL CANASTERO'.
# There are 0 directories and 190 images in 'C:/colab/data/birds/train\AUSTRALASIAN FIGBIRD'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\AVADAVAT'.
# There are 0 directories and 168 images in 'C:/colab/data/birds/train\AZARAS SPINETAIL'.
# There are 0 directories and 141 images in 'C:/colab/data/birds/train\AZURE BREASTED PITTA'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\AZURE JAY'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\AZURE TANAGER'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\AZURE TIT'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\BAIKAL TEAL'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\BALD EAGLE'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\BALD IBIS'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\BALI STARLING'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\BALTIMORE ORIOLE'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\BANANAQUIT'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\BAND TAILED GUAN'.
# There are 0 directories and 194 images in 'C:/colab/data/birds/train\BANDED BROADBILL'.
# There are 0 directories and 166 images in 'C:/colab/data/birds/train\BANDED PITA'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\BANDED STILT'.
# There are 0 directories and 168 images in 'C:/colab/data/birds/train\BAR-TAILED GODWIT'.
# There are 0 directories and 158 images in 'C:/colab/data/birds/train\BARN OWL'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\BARN SWALLOW'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\BARRED PUFFBIRD'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\BARROWS GOLDENEYE'.
# There are 0 directories and 143 images in 'C:/colab/data/birds/train\BAY-BREASTED WARBLER'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\BEARDED BARBET'.
# There are 0 directories and 142 images in 'C:/colab/data/birds/train\BEARDED BELLBIRD'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\BEARDED REEDLING'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\BELTED KINGFISHER'.
# There are 0 directories and 151 images in 'C:/colab/data/birds/train\BIRD OF PARADISE'.
# There are 0 directories and 142 images in 'C:/colab/data/birds/train\BLACK AND YELLOW BROADBILL'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\BLACK BAZA'.
# There are 0 directories and 172 images in 'C:/colab/data/birds/train\BLACK BREASTED PUFFBIRD'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\BLACK COCKATO'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\BLACK FACED SPOONBILL'.
# There are 0 directories and 131 images in 'C:/colab/data/birds/train\BLACK FRANCOLIN'.
# There are 0 directories and 181 images in 'C:/colab/data/birds/train\BLACK HEADED CAIQUE'.
# There are 0 directories and 173 images in 'C:/colab/data/birds/train\BLACK NECKED STILT'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\BLACK SKIMMER'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\BLACK SWAN'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\BLACK TAIL CRAKE'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\BLACK THROATED BUSHTIT'.
# There are 0 directories and 145 images in 'C:/colab/data/birds/train\BLACK THROATED HUET'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\BLACK THROATED WARBLER'.
# There are 0 directories and 188 images in 'C:/colab/data/birds/train\BLACK VENTED SHEARWATER'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\BLACK VULTURE'.
# There are 0 directories and 133 images in 'C:/colab/data/birds/train\BLACK-CAPPED CHICKADEE'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\BLACK-NECKED GREBE'.
# There are 0 directories and 168 images in 'C:/colab/data/birds/train\BLACK-THROATED SPARROW'.
# There are 0 directories and 134 images in 'C:/colab/data/birds/train\BLACKBURNIAM WARBLER'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\BLONDE CRESTED WOODPECKER'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\BLOOD PHEASANT'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\BLUE COAU'.
# There are 0 directories and 173 images in 'C:/colab/data/birds/train\BLUE DACNIS'.
# There are 0 directories and 195 images in 'C:/colab/data/birds/train\BLUE GRAY GNATCATCHER'.
# There are 0 directories and 170 images in 'C:/colab/data/birds/train\BLUE GROSBEAK'.
# There are 0 directories and 185 images in 'C:/colab/data/birds/train\BLUE GROUSE'.
# There are 0 directories and 167 images in 'C:/colab/data/birds/train\BLUE HERON'.
# There are 0 directories and 186 images in 'C:/colab/data/birds/train\BLUE MALKOHA'.
# There are 0 directories and 198 images in 'C:/colab/data/birds/train\BLUE THROATED PIPING GUAN'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\BLUE THROATED TOUCANET'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\BOBOLINK'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\BORNEAN BRISTLEHEAD'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\BORNEAN LEAFBIRD'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\BORNEAN PHEASANT'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\BRANDT CORMARANT'.
# There are 0 directories and 183 images in 'C:/colab/data/birds/train\BREWERS BLACKBIRD'.
# There are 0 directories and 177 images in 'C:/colab/data/birds/train\BROWN CREPPER'.
# There are 0 directories and 192 images in 'C:/colab/data/birds/train\BROWN HEADED COWBIRD'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\BROWN NOODY'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\BROWN THRASHER'.
# There are 0 directories and 184 images in 'C:/colab/data/birds/train\BUFFLEHEAD'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\BULWERS PHEASANT'.
# There are 0 directories and 143 images in 'C:/colab/data/birds/train\BURCHELLS COURSER'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\BUSH TURKEY'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\CAATINGA CACHOLOTE'.
# There are 0 directories and 177 images in 'C:/colab/data/birds/train\CABOTS TRAGOPAN'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\CACTUS WREN'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\CALIFORNIA CONDOR'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\CALIFORNIA GULL'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\CALIFORNIA QUAIL'.
# There are 0 directories and 197 images in 'C:/colab/data/birds/train\CAMPO FLICKER'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\CANARY'.
# There are 0 directories and 185 images in 'C:/colab/data/birds/train\CANVASBACK'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\CAPE GLOSSY STARLING'.
# There are 0 directories and 133 images in 'C:/colab/data/birds/train\CAPE LONGCLAW'.
# There are 0 directories and 149 images in 'C:/colab/data/birds/train\CAPE MAY WARBLER'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\CAPE ROCK THRUSH'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\CAPPED HERON'.
# There are 0 directories and 133 images in 'C:/colab/data/birds/train\CAPUCHINBIRD'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\CARMINE BEE-EATER'.
# There are 0 directories and 213 images in 'C:/colab/data/birds/train\CASPIAN TERN'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\CASSOWARY'.
# There are 0 directories and 180 images in 'C:/colab/data/birds/train\CEDAR WAXWING'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\CERULEAN WARBLER'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\CHARA DE COLLAR'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\CHATTERING LORY'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\CHESTNET BELLIED EUPHONIA'.
# There are 0 directories and 170 images in 'C:/colab/data/birds/train\CHESTNUT WINGED CUCKOO'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\CHINESE BAMBOO PARTRIDGE'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\CHINESE POND HERON'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\CHIPPING SPARROW'.
# There are 0 directories and 141 images in 'C:/colab/data/birds/train\CHUCAO TAPACULO'.
# There are 0 directories and 167 images in 'C:/colab/data/birds/train\CHUKAR PARTRIDGE'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\CINNAMON ATTILA'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\CINNAMON FLYCATCHER'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\CINNAMON TEAL'.
# There are 0 directories and 182 images in 'C:/colab/data/birds/train\CLARKS GREBE'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\CLARKS NUTCRACKER'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\COCK OF THE  ROCK'.
# There are 0 directories and 166 images in 'C:/colab/data/birds/train\COCKATOO'.
# There are 0 directories and 177 images in 'C:/colab/data/birds/train\COLLARED ARACARI'.
# There are 0 directories and 172 images in 'C:/colab/data/birds/train\COLLARED CRESCENTCHEST'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\COMMON FIRECREST'.
# There are 0 directories and 177 images in 'C:/colab/data/birds/train\COMMON GRACKLE'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\COMMON HOUSE MARTIN'.
# There are 0 directories and 133 images in 'C:/colab/data/birds/train\COMMON IORA'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\COMMON LOON'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\COMMON POORWILL'.
# There are 0 directories and 141 images in 'C:/colab/data/birds/train\COMMON STARLING'.
# There are 0 directories and 196 images in 'C:/colab/data/birds/train\COPPERSMITH BARBET'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\COPPERY TAILED COUCAL'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\CRAB PLOVER'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\CRANE HAWK'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\CREAM COLORED WOODPECKER'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\CRESTED AUKLET'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\CRESTED CARACARA'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\CRESTED COUA'.
# There are 0 directories and 142 images in 'C:/colab/data/birds/train\CRESTED FIREBACK'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\CRESTED KINGFISHER'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\CRESTED NUTHATCH'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\CRESTED OROPENDOLA'.
# There are 0 directories and 181 images in 'C:/colab/data/birds/train\CRESTED SERPENT EAGLE'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\CRESTED SHRIKETIT'.
# There are 0 directories and 197 images in 'C:/colab/data/birds/train\CRESTED WOOD PARTRIDGE'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\CRIMSON CHAT'.
# There are 0 directories and 198 images in 'C:/colab/data/birds/train\CRIMSON SUNBIRD'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\CROW'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\CUBAN TODY'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\CUBAN TROGON'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\CURL CRESTED ARACURI'.
# There are 0 directories and 233 images in 'C:/colab/data/birds/train\D-ARNAUDS BARBET'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\DALMATIAN PELICAN'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\DARJEELING WOODPECKER'.
# There are 0 directories and 203 images in 'C:/colab/data/birds/train\DARK EYED JUNCO'.
# There are 0 directories and 146 images in 'C:/colab/data/birds/train\DAURIAN REDSTART'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\DEMOISELLE CRANE'.
# There are 0 directories and 148 images in 'C:/colab/data/birds/train\DOUBLE BARRED FINCH'.
# There are 0 directories and 185 images in 'C:/colab/data/birds/train\DOUBLE BRESTED CORMARANT'.
# There are 0 directories and 166 images in 'C:/colab/data/birds/train\DOUBLE EYED FIG PARROT'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\DOWNY WOODPECKER'.
# There are 0 directories and 190 images in 'C:/colab/data/birds/train\DUNLIN'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\DUSKY LORY'.
# There are 0 directories and 140 images in 'C:/colab/data/birds/train\DUSKY ROBIN'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\EARED PITA'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\EASTERN BLUEBIRD'.
# There are 0 directories and 134 images in 'C:/colab/data/birds/train\EASTERN BLUEBONNET'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\EASTERN GOLDEN WEAVER'.
# There are 0 directories and 190 images in 'C:/colab/data/birds/train\EASTERN MEADOWLARK'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\EASTERN ROSELLA'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\EASTERN TOWEE'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\EASTERN WIP POOR WILL'.
# There are 0 directories and 205 images in 'C:/colab/data/birds/train\EASTERN YELLOW ROBIN'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\ECUADORIAN HILLSTAR'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\EGYPTIAN GOOSE'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\ELEGANT TROGON'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\ELLIOTS  PHEASANT'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\EMERALD TANAGER'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\EMPEROR PENGUIN'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\EMU'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\ENGGANO MYNA'.
# There are 0 directories and 166 images in 'C:/colab/data/birds/train\EURASIAN BULLFINCH'.
# There are 0 directories and 130 images in 'C:/colab/data/birds/train\EURASIAN GOLDEN ORIOLE'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\EURASIAN MAGPIE'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\EUROPEAN GOLDFINCH'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\EUROPEAN TURTLE DOVE'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\EVENING GROSBEAK'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\FAIRY BLUEBIRD'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\FAIRY PENGUIN'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\FAIRY TERN'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\FAN TAILED WIDOW'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\FASCIATED WREN'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\FIERY MINIVET'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\FIORDLAND PENGUIN'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\FIRE TAILLED MYZORNIS'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\FLAME BOWERBIRD'.
# There are 0 directories and 177 images in 'C:/colab/data/birds/train\FLAME TANAGER'.
# There are 0 directories and 172 images in 'C:/colab/data/birds/train\FOREST WAGTAIL'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\FRIGATE'.
# There are 0 directories and 209 images in 'C:/colab/data/birds/train\FRILL BACK PIGEON'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\GAMBELS QUAIL'.
# There are 0 directories and 142 images in 'C:/colab/data/birds/train\GANG GANG COCKATOO'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\GILA WOODPECKER'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\GILDED FLICKER'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\GLOSSY IBIS'.
# There are 0 directories and 131 images in 'C:/colab/data/birds/train\GO AWAY BIRD'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\GOLD WING WARBLER'.
# There are 0 directories and 140 images in 'C:/colab/data/birds/train\GOLDEN BOWER BIRD'.
# There are 0 directories and 176 images in 'C:/colab/data/birds/train\GOLDEN CHEEKED WARBLER'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\GOLDEN CHLOROPHONIA'.
# There are 0 directories and 158 images in 'C:/colab/data/birds/train\GOLDEN EAGLE'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\GOLDEN PARAKEET'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\GOLDEN PHEASANT'.
# There are 0 directories and 158 images in 'C:/colab/data/birds/train\GOLDEN PIPIT'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\GOULDIAN FINCH'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\GRANDALA'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\GRAY CATBIRD'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\GRAY KINGBIRD'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\GRAY PARTRIDGE'.
# There are 0 directories and 189 images in 'C:/colab/data/birds/train\GREAT ARGUS'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\GREAT GRAY OWL'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\GREAT JACAMAR'.
# There are 0 directories and 169 images in 'C:/colab/data/birds/train\GREAT KISKADEE'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\GREAT POTOO'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\GREAT TINAMOU'.
# There are 0 directories and 149 images in 'C:/colab/data/birds/train\GREAT XENOPS'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\GREATER PEWEE'.
# There are 0 directories and 203 images in 'C:/colab/data/birds/train\GREATER PRAIRIE CHICKEN'.
# There are 0 directories and 184 images in 'C:/colab/data/birds/train\GREATOR SAGE GROUSE'.
# There are 0 directories and 140 images in 'C:/colab/data/birds/train\GREEN BROADBILL'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\GREEN JAY'.
# There are 0 directories and 176 images in 'C:/colab/data/birds/train\GREEN MAGPIE'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\GREEN WINGED DOVE'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\GREY CUCKOOSHRIKE'.
# There are 0 directories and 199 images in 'C:/colab/data/birds/train\GREY HEADED CHACHALACA'.
# There are 0 directories and 143 images in 'C:/colab/data/birds/train\GREY HEADED FISH EAGLE'.
# There are 0 directories and 158 images in 'C:/colab/data/birds/train\GREY PLOVER'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\GROVED BILLED ANI'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\GUINEA TURACO'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\GUINEAFOWL'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\GURNEYS PITTA'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\GYRFALCON'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\HAMERKOP'.
# There are 0 directories and 151 images in 'C:/colab/data/birds/train\HARLEQUIN DUCK'.
# There are 0 directories and 134 images in 'C:/colab/data/birds/train\HARLEQUIN QUAIL'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\HARPY EAGLE'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\HAWAIIAN GOOSE'.
# There are 0 directories and 167 images in 'C:/colab/data/birds/train\HAWFINCH'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\HELMET VANGA'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\HEPATIC TANAGER'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\HIMALAYAN BLUETAIL'.
# There are 0 directories and 151 images in 'C:/colab/data/birds/train\HIMALAYAN MONAL'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\HOATZIN'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\HOODED MERGANSER'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\HOOPOES'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\HORNED GUAN'.
# There are 0 directories and 173 images in 'C:/colab/data/birds/train\HORNED LARK'.
# There are 0 directories and 149 images in 'C:/colab/data/birds/train\HORNED SUNGEM'.
# There are 0 directories and 248 images in 'C:/colab/data/birds/train\HOUSE FINCH'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\HOUSE SPARROW'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\HYACINTH MACAW'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\IBERIAN MAGPIE'.
# There are 0 directories and 141 images in 'C:/colab/data/birds/train\IBISBILL'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\IMPERIAL SHAQ'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\INCA TERN'.
# There are 0 directories and 131 images in 'C:/colab/data/birds/train\INDIAN BUSTARD'.
# There are 0 directories and 186 images in 'C:/colab/data/birds/train\INDIAN PITTA'.
# There are 0 directories and 183 images in 'C:/colab/data/birds/train\INDIAN ROLLER'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\INDIAN VULTURE'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\INDIGO BUNTING'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\INDIGO FLYCATCHER'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\INLAND DOTTEREL'.
# There are 0 directories and 149 images in 'C:/colab/data/birds/train\IVORY BILLED ARACARI'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\IVORY GULL'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\IWI'.
# There are 0 directories and 143 images in 'C:/colab/data/birds/train\JABIRU'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\JACK SNIPE'.
# There are 0 directories and 204 images in 'C:/colab/data/birds/train\JACOBIN PIGEON'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\JANDAYA PARAKEET'.
# There are 0 directories and 158 images in 'C:/colab/data/birds/train\JAPANESE ROBIN'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\JAVA SPARROW'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\JOCOTOCO ANTPITTA'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\KAGU'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\KAKAPO'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\KILLDEAR'.
# There are 0 directories and 170 images in 'C:/colab/data/birds/train\KING EIDER'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\KING VULTURE'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\KIWI'.
# There are 0 directories and 197 images in 'C:/colab/data/birds/train\KNOB BILLED DUCK'.
# There are 0 directories and 143 images in 'C:/colab/data/birds/train\KOOKABURRA'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\LARK BUNTING'.
# There are 0 directories and 206 images in 'C:/colab/data/birds/train\LAUGHING GULL'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\LAZULI BUNTING'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\LESSER ADJUTANT'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\LILAC ROLLER'.
# There are 0 directories and 200 images in 'C:/colab/data/birds/train\LIMPKIN'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\LITTLE AUK'.
# There are 0 directories and 190 images in 'C:/colab/data/birds/train\LOGGERHEAD SHRIKE'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\LONG-EARED OWL'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\LOONEY BIRDS'.
# There are 0 directories and 168 images in 'C:/colab/data/birds/train\LUCIFER HUMMINGBIRD'.
# There are 0 directories and 142 images in 'C:/colab/data/birds/train\MAGPIE GOOSE'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\MALABAR HORNBILL'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\MALACHITE KINGFISHER'.
# There are 0 directories and 143 images in 'C:/colab/data/birds/train\MALAGASY WHITE EYE'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\MALEO'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\MALLARD DUCK'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\MANDRIN DUCK'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\MANGROVE CUCKOO'.
# There are 0 directories and 197 images in 'C:/colab/data/birds/train\MARABOU STORK'.
# There are 0 directories and 183 images in 'C:/colab/data/birds/train\MASKED BOBWHITE'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\MASKED BOOBY'.
# There are 0 directories and 131 images in 'C:/colab/data/birds/train\MASKED LAPWING'.
# There are 0 directories and 187 images in 'C:/colab/data/birds/train\MCKAYS BUNTING'.
# There are 0 directories and 209 images in 'C:/colab/data/birds/train\MERLIN'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\MIKADO  PHEASANT'.
# There are 0 directories and 208 images in 'C:/colab/data/birds/train\MILITARY MACAW'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\MOURNING DOVE'.
# There are 0 directories and 141 images in 'C:/colab/data/birds/train\MYNA'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\NICOBAR PIGEON'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\NOISY FRIARBIRD'.
# There are 0 directories and 185 images in 'C:/colab/data/birds/train\NORTHERN BEARDLESS TYRANNULET'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\NORTHERN CARDINAL'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\NORTHERN FLICKER'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\NORTHERN FULMAR'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\NORTHERN GANNET'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\NORTHERN GOSHAWK'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\NORTHERN JACANA'.
# There are 0 directories and 140 images in 'C:/colab/data/birds/train\NORTHERN MOCKINGBIRD'.
# There are 0 directories and 196 images in 'C:/colab/data/birds/train\NORTHERN PARULA'.
# There are 0 directories and 130 images in 'C:/colab/data/birds/train\NORTHERN RED BISHOP'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\NORTHERN SHOVELER'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\OCELLATED TURKEY'.
# There are 0 directories and 182 images in 'C:/colab/data/birds/train\OILBIRD'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\OKINAWA RAIL'.
# There are 0 directories and 192 images in 'C:/colab/data/birds/train\ORANGE BREASTED TROGON'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\ORANGE BRESTED BUNTING'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\ORIENTAL BAY OWL'.
# There are 0 directories and 208 images in 'C:/colab/data/birds/train\ORNATE HAWK EAGLE'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\OSPREY'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\OSTRICH'.
# There are 0 directories and 233 images in 'C:/colab/data/birds/train\OVENBIRD'.
# There are 0 directories and 207 images in 'C:/colab/data/birds/train\OYSTER CATCHER'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\PAINTED BUNTING'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\PALILA'.
# There are 0 directories and 192 images in 'C:/colab/data/birds/train\PALM NUT VULTURE'.
# There are 0 directories and 176 images in 'C:/colab/data/birds/train\PARADISE TANAGER'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\PARAKETT  AUKLET'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\PARUS MAJOR'.
# There are 0 directories and 130 images in 'C:/colab/data/birds/train\PATAGONIAN SIERRA FINCH'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\PEACOCK'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\PEREGRINE FALCON'.
# There are 0 directories and 188 images in 'C:/colab/data/birds/train\PHAINOPEPLA'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\PHILIPPINE EAGLE'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\PINK ROBIN'.
# There are 0 directories and 200 images in 'C:/colab/data/birds/train\PLUSH CRESTED JAY'.
# There are 0 directories and 140 images in 'C:/colab/data/birds/train\POMARINE JAEGER'.
# There are 0 directories and 166 images in 'C:/colab/data/birds/train\PUFFIN'.
# There are 0 directories and 185 images in 'C:/colab/data/birds/train\PUNA TEAL'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\PURPLE FINCH'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\PURPLE GALLINULE'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\PURPLE MARTIN'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\PURPLE SWAMPHEN'.
# There are 0 directories and 173 images in 'C:/colab/data/birds/train\PYGMY KINGFISHER'.
# There are 0 directories and 209 images in 'C:/colab/data/birds/train\PYRRHULOXIA'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\QUETZAL'.
# There are 0 directories and 140 images in 'C:/colab/data/birds/train\RAINBOW LORIKEET'.
# There are 0 directories and 193 images in 'C:/colab/data/birds/train\RAZORBILL'.
# There are 0 directories and 197 images in 'C:/colab/data/birds/train\RED BEARDED BEE EATER'.
# There are 0 directories and 146 images in 'C:/colab/data/birds/train\RED BELLIED PITTA'.
# There are 0 directories and 212 images in 'C:/colab/data/birds/train\RED BILLED TROPICBIRD'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\RED BROWED FINCH'.
# There are 0 directories and 191 images in 'C:/colab/data/birds/train\RED CROSSBILL'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\RED FACED CORMORANT'.
# There are 0 directories and 167 images in 'C:/colab/data/birds/train\RED FACED WARBLER'.
# There are 0 directories and 167 images in 'C:/colab/data/birds/train\RED FODY'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\RED HEADED DUCK'.
# There are 0 directories and 133 images in 'C:/colab/data/birds/train\RED HEADED WOODPECKER'.
# There are 0 directories and 200 images in 'C:/colab/data/birds/train\RED KNOT'.
# There are 0 directories and 169 images in 'C:/colab/data/birds/train\RED LEGGED HONEYCREEPER'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\RED NAPED TROGON'.
# There are 0 directories and 172 images in 'C:/colab/data/birds/train\RED SHOULDERED HAWK'.
# There are 0 directories and 202 images in 'C:/colab/data/birds/train\RED TAILED HAWK'.
# There are 0 directories and 130 images in 'C:/colab/data/birds/train\RED TAILED THRUSH'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\RED WINGED BLACKBIRD'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\RED WISKERED BULBUL'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\REGENT BOWERBIRD'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\RING-NECKED PHEASANT'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\ROADRUNNER'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\ROCK DOVE'.
# There are 0 directories and 197 images in 'C:/colab/data/birds/train\ROSE BREASTED COCKATOO'.
# There are 0 directories and 174 images in 'C:/colab/data/birds/train\ROSE BREASTED GROSBEAK'.
# There are 0 directories and 193 images in 'C:/colab/data/birds/train\ROSEATE SPOONBILL'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\ROSY FACED LOVEBIRD'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\ROUGH LEG BUZZARD'.
# There are 0 directories and 142 images in 'C:/colab/data/birds/train\ROYAL FLYCATCHER'.
# There are 0 directories and 186 images in 'C:/colab/data/birds/train\RUBY CROWNED KINGLET'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\RUBY THROATED HUMMINGBIRD'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\RUDDY SHELDUCK'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\RUDY KINGFISHER'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\RUFOUS KINGFISHER'.
# There are 0 directories and 263 images in 'C:/colab/data/birds/train\RUFOUS TREPE'.
# There are 0 directories and 189 images in 'C:/colab/data/birds/train\RUFUOS MOTMOT'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\SAMATRAN THRUSH'.
# There are 0 directories and 151 images in 'C:/colab/data/birds/train\SAND MARTIN'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\SANDHILL CRANE'.
# There are 0 directories and 169 images in 'C:/colab/data/birds/train\SATYR TRAGOPAN'.
# There are 0 directories and 197 images in 'C:/colab/data/birds/train\SAYS PHOEBE'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\SCARLET CROWNED FRUIT DOVE'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\SCARLET FACED LIOCICHLA'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\SCARLET IBIS'.
# There are 0 directories and 157 images in 'C:/colab/data/birds/train\SCARLET MACAW'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\SCARLET TANAGER'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\SHOEBILL'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\SHORT BILLED DOWITCHER'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\SMITHS LONGSPUR'.
# There are 0 directories and 190 images in 'C:/colab/data/birds/train\SNOW GOOSE'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\SNOW PARTRIDGE'.
# There are 0 directories and 132 images in 'C:/colab/data/birds/train\SNOWY EGRET'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\SNOWY OWL'.
# There are 0 directories and 130 images in 'C:/colab/data/birds/train\SNOWY PLOVER'.
# There are 0 directories and 187 images in 'C:/colab/data/birds/train\SNOWY SHEATHBILL'.
# There are 0 directories and 200 images in 'C:/colab/data/birds/train\SORA'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\SPANGLED COTINGA'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\SPLENDID WREN'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\SPOON BILED SANDPIPER'.
# There are 0 directories and 150 images in 'C:/colab/data/birds/train\SPOTTED CATBIRD'.
# There are 0 directories and 184 images in 'C:/colab/data/birds/train\SPOTTED WHISTLING DUCK'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\SQUACCO HERON'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\SRI LANKA BLUE MAGPIE'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\STEAMER DUCK'.
# There are 0 directories and 135 images in 'C:/colab/data/birds/train\STORK BILLED KINGFISHER'.
# There are 0 directories and 196 images in 'C:/colab/data/birds/train\STRIATED CARACARA'.
# There are 0 directories and 143 images in 'C:/colab/data/birds/train\STRIPED OWL'.
# There are 0 directories and 144 images in 'C:/colab/data/birds/train\STRIPPED MANAKIN'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\STRIPPED SWALLOW'.
# There are 0 directories and 169 images in 'C:/colab/data/birds/train\SUNBITTERN'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\SUPERB STARLING'.
# There are 0 directories and 185 images in 'C:/colab/data/birds/train\SURF SCOTER'.
# There are 0 directories and 216 images in 'C:/colab/data/birds/train\SWINHOES PHEASANT'.
# There are 0 directories and 141 images in 'C:/colab/data/birds/train\TAILORBIRD'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\TAIWAN MAGPIE'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\TAKAHE'.
# There are 0 directories and 131 images in 'C:/colab/data/birds/train\TASMANIAN HEN'.
# There are 0 directories and 187 images in 'C:/colab/data/birds/train\TAWNY FROGMOUTH'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\TEAL DUCK'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\TIT MOUSE'.
# There are 0 directories and 136 images in 'C:/colab/data/birds/train\TOUCHAN'.
# There are 0 directories and 165 images in 'C:/colab/data/birds/train\TOWNSENDS WARBLER'.
# There are 0 directories and 181 images in 'C:/colab/data/birds/train\TREE SWALLOW'.
# There are 0 directories and 139 images in 'C:/colab/data/birds/train\TRICOLORED BLACKBIRD'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\TROPICAL KINGBIRD'.
# There are 0 directories and 137 images in 'C:/colab/data/birds/train\TRUMPTER SWAN'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\TURKEY VULTURE'.
# There are 0 directories and 156 images in 'C:/colab/data/birds/train\TURQUOISE MOTMOT'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\UMBRELLA BIRD'.
# There are 0 directories and 193 images in 'C:/colab/data/birds/train\VARIED THRUSH'.
# There are 0 directories and 190 images in 'C:/colab/data/birds/train\VEERY'.
# There are 0 directories and 152 images in 'C:/colab/data/birds/train\VENEZUELIAN TROUPIAL'.
# There are 0 directories and 182 images in 'C:/colab/data/birds/train\VERDIN'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\VERMILION FLYCATHER'.
# There are 0 directories and 151 images in 'C:/colab/data/birds/train\VICTORIA CROWNED PIGEON'.
# There are 0 directories and 201 images in 'C:/colab/data/birds/train\VIOLET BACKED STARLING'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\VIOLET CUCKOO'.
# There are 0 directories and 201 images in 'C:/colab/data/birds/train\VIOLET GREEN SWALLOW'.
# There are 0 directories and 162 images in 'C:/colab/data/birds/train\VIOLET TURACO'.
# There are 0 directories and 163 images in 'C:/colab/data/birds/train\VISAYAN HORNBILL'.
# There are 0 directories and 169 images in 'C:/colab/data/birds/train\VULTURINE GUINEAFOWL'.
# There are 0 directories and 172 images in 'C:/colab/data/birds/train\WALL CREAPER'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\WATTLED CURASSOW'.
# There are 0 directories and 142 images in 'C:/colab/data/birds/train\WATTLED LAPWING'.
# There are 0 directories and 138 images in 'C:/colab/data/birds/train\WHIMBREL'.
# There are 0 directories and 161 images in 'C:/colab/data/birds/train\WHITE BREASTED WATERHEN'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\WHITE BROWED CRAKE'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\WHITE CHEEKED TURACO'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\WHITE CRESTED HORNBILL'.
# There are 0 directories and 176 images in 'C:/colab/data/birds/train\WHITE EARED HUMMINGBIRD'.
# There are 0 directories and 160 images in 'C:/colab/data/birds/train\WHITE NECKED RAVEN'.
# There are 0 directories and 175 images in 'C:/colab/data/birds/train\WHITE TAILED TROPIC'.
# There are 0 directories and 164 images in 'C:/colab/data/birds/train\WHITE THROATED BEE EATER'.
# There are 0 directories and 153 images in 'C:/colab/data/birds/train\WILD TURKEY'.
# There are 0 directories and 195 images in 'C:/colab/data/birds/train\WILLOW PTARMIGAN'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\WILSONS BIRD OF PARADISE'.
# There are 0 directories and 214 images in 'C:/colab/data/birds/train\WOOD DUCK'.
# There are 0 directories and 211 images in 'C:/colab/data/birds/train\WOOD THRUSH'.
# There are 0 directories and 194 images in 'C:/colab/data/birds/train\WOODLAND KINGFISHER'.
# There are 0 directories and 193 images in 'C:/colab/data/birds/train\WRENTIT'.
# There are 0 directories and 154 images in 'C:/colab/data/birds/train\YELLOW BELLIED FLOWERPECKER'.
# There are 0 directories and 202 images in 'C:/colab/data/birds/train\YELLOW BREASTED CHAT'.
# There are 0 directories and 155 images in 'C:/colab/data/birds/train\YELLOW CACIQUE'.
# There are 0 directories and 159 images in 'C:/colab/data/birds/train\YELLOW HEADED BLACKBIRD'.
# There are 0 directories and 170 images in 'C:/colab/data/birds/train\ZEBRA DOVE'.
# There are 525 directories and 0 images in 'C:/colab/data/birds/test'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ABBOTTS BABBLER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ABBOTTS BOOBY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ABYSSINIAN GROUND HORNBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AFRICAN CROWNED CRANE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AFRICAN EMERALD CUCKOO'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AFRICAN FIREFINCH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AFRICAN OYSTER CATCHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AFRICAN PIED HORNBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AFRICAN PYGMY GOOSE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ALBATROSS'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ALBERTS TOWHEE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ALEXANDRINE PARAKEET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ALPINE CHOUGH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\ALTAMIRA YELLOWTHROAT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN AVOCET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN BITTERN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN COOT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN DIPPER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN FLAMINGO'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN GOLDFINCH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN KESTREL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN PIPIT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN REDSTART'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN ROBIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMERICAN WIGEON'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/test\AMETHYST WOODSTAR'.
# ...
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MALLARD DUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MANDRIN DUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MANGROVE CUCKOO'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MARABOU STORK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MASKED BOBWHITE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MASKED BOOBY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MASKED LAPWING'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MCKAYS BUNTING'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MERLIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MIKADO  PHEASANT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MILITARY MACAW'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MOURNING DOVE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\MYNA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NICOBAR PIGEON'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NOISY FRIARBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN BEARDLESS TYRANNULET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN CARDINAL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN FLICKER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN FULMAR'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN GANNET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN GOSHAWK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN JACANA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN MOCKINGBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN PARULA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN RED BISHOP'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\NORTHERN SHOVELER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\OCELLATED TURKEY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\OILBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\OKINAWA RAIL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ORANGE BREASTED TROGON'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ORANGE BRESTED BUNTING'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ORIENTAL BAY OWL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ORNATE HAWK EAGLE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\OSPREY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\OSTRICH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\OVENBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\OYSTER CATCHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PAINTED BUNTING'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PALILA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PALM NUT VULTURE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PARADISE TANAGER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PARAKETT AUKLET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PARUS MAJOR'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PATAGONIAN SIERRA FINCH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PEACOCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PEREGRINE FALCON'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PHAINOPEPLA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PHILIPPINE EAGLE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PINK ROBIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PLUSH CRESTED JAY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\POMARINE JAEGER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PUFFIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PUNA TEAL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PURPLE FINCH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PURPLE GALLINULE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PURPLE MARTIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PURPLE SWAMPHEN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PYGMY KINGFISHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\PYRRHULOXIA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\QUETZAL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RAINBOW LORIKEET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RAZORBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED BEARDED BEE EATER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED BELLIED PITTA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED BILLED TROPICBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED BROWED FINCH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED CROSSBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED FACED CORMORANT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED FACED WARBLER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED FODY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED HEADED DUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED HEADED WOODPECKER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED KNOT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED LEGGED HONEYCREEPER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED NAPED TROGON'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED SHOULDERED HAWK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED TAILED HAWK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED TAILED THRUSH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED WINGED BLACKBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RED WISKERED BULBUL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\REGENT BOWERBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RING-NECKED PHEASANT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROADRUNNER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROCK DOVE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROSE BREASTED COCKATOO'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROSE BREASTED GROSBEAK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROSEATE SPOONBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROSY FACED LOVEBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROUGH LEG BUZZARD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ROYAL FLYCATCHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RUBY CROWNED KINGLET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RUBY THROATED HUMMINGBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RUDDY SHELDUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RUDY KINGFISHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RUFOUS KINGFISHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RUFOUS TREPE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\RUFUOS MOTMOT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SAMATRAN THRUSH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SAND MARTIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SANDHILL CRANE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SATYR TRAGOPAN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SAYS PHOEBE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SCARLET CROWNED FRUIT DOVE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SCARLET FACED LIOCICHLA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SCARLET IBIS'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SCARLET MACAW'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SCARLET TANAGER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SHOEBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SHORT BILLED DOWITCHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SMITHS LONGSPUR'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SNOW GOOSE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SNOW PARTRIDGE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SNOWY EGRET'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SNOWY OWL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SNOWY PLOVER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SNOWY SHEATHBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SORA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SPANGLED COTINGA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SPLENDID WREN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SPOON BILED SANDPIPER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SPOTTED CATBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SPOTTED WHISTLING DUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SQUACCO HERON'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SRI LANKA BLUE MAGPIE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\STEAMER DUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\STORK BILLED KINGFISHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\STRIATED CARACARA'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\STRIPED OWL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\STRIPPED MANAKIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\STRIPPED SWALLOW'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SUNBITTERN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SUPERB STARLING'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SURF SCOTER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\SWINHOES PHEASANT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TAILORBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TAIWAN MAGPIE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TAKAHE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TASMANIAN HEN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TAWNY FROGMOUTH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TEAL DUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TIT MOUSE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TOUCHAN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TOWNSENDS WARBLER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TREE SWALLOW'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TRICOLORED BLACKBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TROPICAL KINGBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TRUMPTER SWAN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TURKEY VULTURE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\TURQUOISE MOTMOT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\UMBRELLA BIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VARIED THRUSH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VEERY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VENEZUELIAN TROUPIAL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VERDIN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VERMILION FLYCATHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VICTORIA CROWNED PIGEON'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VIOLET BACKED STARLING'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VIOLET CUCKOO'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VIOLET GREEN SWALLOW'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VIOLET TURACO'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VISAYAN HORNBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\VULTURINE GUINEAFOWL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WALL CREAPER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WATTLED CURASSOW'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WATTLED LAPWING'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHIMBREL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE BREASTED WATERHEN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE BROWED CRAKE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE CHEEKED TURACO'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE CRESTED HORNBILL'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE EARED HUMMINGBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE NECKED RAVEN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE TAILED TROPIC'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WHITE THROATED BEE EATER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WILD TURKEY'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WILLOW PTARMIGAN'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WILSONS BIRD OF PARADISE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WOOD DUCK'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WOOD THRUSH'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WOODLAND KINGFISHER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\WRENTIT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\YELLOW BELLIED FLOWERPECKER'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\YELLOW BREASTED CHAT'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\YELLOW CACIQUE'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\YELLOW HEADED BLACKBIRD'.
# There are 0 directories and 5 images in 'C:/colab/data/birds/valid\ZEBRA DOVE'.
# Found 66262 validated image filenames belonging to 410 classes.
# Found 2050 validated image filenames belonging to 410 classes.
# Found 2050 validated image filenames belonging to 410 classes.

# %%
print("Starting model testing")
model_path = 'C:/colab/data/birds/bird_classifier-84.tflite'
tflite_interpreter = tf.lite.Interpreter(model_path=model_path)
input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

tflite_interpreter.resize_tensor_input(input_details[0]['index'], (32, 96, 96, 3))
tflite_interpreter.resize_tensor_input(output_details[0]['index'], (32, 5))
tflite_interpreter.allocate_tensors()

model_size_bytes = os.path.getsize(model_path)

  
print(f"Model Size: {model_size_bytes} bytes")

input_batch, _ = next(test_images)


results = []

for i in range(len(test_images)):
    batch = test_images[i]
    input_batch, labels = batch
    image_input_batch = tf.cast(input_batch, tf.int8)

    input_scale, input_zero_point = input_details[0]["quantization"]
    image_input_batch = tf.cast(image_input_batch, tf.float32)
    image_input_batch = (image_input_batch / input_scale) + input_zero_point
    image_input_batch = tf.cast(image_input_batch, tf.int8)

    if len(image_input_batch) == 32:
        tflite_interpreter.set_tensor(input_details[0]['index'], image_input_batch)
        tflite_interpreter.invoke()
        tflite_model_predictions = tflite_interpreter.get_tensor(output_details[0]['index'])
    
        tflite_predicted_ids = np.argmax(tflite_model_predictions, axis=-1)
        tflite_label_id = np.argmax(labels, axis=-1)
    
        correct_predictions = np.sum(tflite_predicted_ids == tflite_label_id)
        total_predictions = len(tflite_predicted_ids)
        accuracy_percentage = (correct_predictions / total_predictions) * 100
    
        results.append(accuracy_percentage)
        average_accuracy = sum(results) / len(results)
        print("\nIteration ", i, ": ", accuracy_percentage, " - Running Average: ", average_accuracy)

print("\nEnd Average: ", average_accuracy)
# Out:
# Starting model testing
# Model Size: 227480 bytes
#
# Iteration  0 :  71.875  - Running Average:  71.875
#
# Iteration  1 :  65.625  - Running Average:  68.75
#
# Iteration  2 :  65.625  - Running Average:  67.70833333333333
#
# Iteration  3 :  90.625  - Running Average:  73.4375
#
# Iteration  4 :  78.125  - Running Average:  74.375
#
# Iteration  5 :  96.875  - Running Average:  78.125
#
# Iteration  6 :  84.375  - Running Average:  79.01785714285714
#
# Iteration  7 :  90.625  - Running Average:  80.46875
#
# Iteration  8 :  68.75  - Running Average:  79.16666666666667
#
# Iteration  9 :  84.375  - Running Average:  79.6875
#
# Iteration  10 :  81.25  - Running Average:  79.82954545454545
#
# Iteration  11 :  90.625  - Running Average:  80.72916666666667
#
# Iteration  12 :  78.125  - Running Average:  80.52884615384616
#
# Iteration  13 :  75.0  - Running Average:  80.13392857142857
#
# Iteration  14 :  71.875  - Running Average:  79.58333333333333
#
# Iteration  15 :  81.25  - Running Average:  79.6875
#
# Iteration  16 :  100.0  - Running Average:  80.88235294117646
#
# Iteration  17 :  87.5  - Running Average:  81.25
#
# Iteration  18 :  100.0  - Running Average:  82.23684210526316
#
# Iteration  19 :  96.875  - Running Average:  82.96875
#
# Iteration  20 :  81.25  - Running Average:  82.88690476190476
#
# Iteration  21 :  81.25  - Running Average:  82.8125
#
# Iteration  22 :  87.5  - Running Average:  83.0163043478261
#
# Iteration  23 :  81.25  - Running Average:  82.94270833333333
#
# Iteration  24 :  75.0  - Running Average:  82.625
#
# Iteration  25 :  87.5  - Running Average:  82.8125
#
# Iteration  26 :  75.0  - Running Average:  82.52314814814815
#
# Iteration  27 :  84.375  - Running Average:  82.58928571428571
#
# Iteration  28 :  90.625  - Running Average:  82.86637931034483
#
# Iteration  29 :  90.625  - Running Average:  83.125
#
# Iteration  30 :  93.75  - Running Average:  83.46774193548387
#
# Iteration  31 :  87.5  - Running Average:  83.59375
#
# Iteration  32 :  87.5  - Running Average:  83.71212121212122
#
# Iteration  33 :  90.625  - Running Average:  83.9154411764706
#
# Iteration  34 :  93.75  - Running Average:  84.19642857142857
#
# Iteration  35 :  93.75  - Running Average:  84.46180555555556
#
# Iteration  36 :  84.375  - Running Average:  84.45945945945945
#
# Iteration  37 :  81.25  - Running Average:  84.375
#
# Iteration  38 :  78.125  - Running Average:  84.21474358974359
#
# Iteration  39 :  93.75  - Running Average:  84.453125
#
# Iteration  40 :  84.375  - Running Average:  84.45121951219512
#
# Iteration  41 :  90.625  - Running Average:  84.59821428571429
#
# Iteration  42 :  84.375  - Running Average:  84.59302325581395
#
# Iteration  43 :  75.0  - Running Average:  84.375
#
# Iteration  44 :  75.0  - Running Average:  84.16666666666667
#
# Iteration  45 :  90.625  - Running Average:  84.3070652173913
#
# Iteration  46 :  100.0  - Running Average:  84.64095744680851
#
# Iteration  47 :  84.375  - Running Average:  84.63541666666667
#
# Iteration  48 :  84.375  - Running Average:  84.63010204081633
#
# Iteration  49 :  93.75  - Running Average:  84.8125
#
# Iteration  50 :  84.375  - Running Average:  84.80392156862744
#
# Iteration  51 :  90.625  - Running Average:  84.91586538461539
#
# Iteration  52 :  90.625  - Running Average:  85.02358490566037
#
# Iteration  53 :  87.5  - Running Average:  85.06944444444444
#
# Iteration  54 :  78.125  - Running Average:  84.94318181818181
#
# Iteration  55 :  81.25  - Running Average:  84.87723214285714
#
# Iteration  56 :  65.625  - Running Average:  84.53947368421052
#
# Iteration  57 :  78.125  - Running Average:  84.42887931034483
#
# Iteration  58 :  81.25  - Running Average:  84.375
#
# Iteration  59 :  87.5  - Running Average:  84.42708333333333
#
# Iteration  60 :  78.125  - Running Average:  84.32377049180327
#
# Iteration  61 :  84.375  - Running Average:  84.32459677419355
#
# Iteration  62 :  71.875  - Running Average:  84.12698412698413
#
# Iteration  63 :  78.125  - Running Average:  84.033203125
#
# End Average:  84.033203125

# %%
model_h_path = "C:/colab/data/birds/model.h"

with open(model_path, "rb") as tflite_file:
    model_data = tflite_file.read()
    model_hex_array = ', '.join(f'0x{byte:02X}' for byte in model_data)


with open(model_h_path, "w") as model_h_file:
    model_h_file.write(f"const unsigned char model[] __attribute__((aligned(4))) = {{\n    {model_hex_array}\n}};\n")


model_h_size = os.path.getsize(model_h_path)
print(f"Header file, model.h, is {model_h_size:,} bytes.")
# Out:
# Header file, model.h, is 1,364,949 bytes.

# %%
import csv

def generate_c_function(csv_file_path, output_file_path):
    # Load labels from CSV
    labels = {}
    with open(csv_file_path, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            labels[int(row['ClassIndex'])] = row['Label']

    # Generate C function
    c_function = "#include <stdio.h>\n\n"
    c_function += "const char* getBirdLabel(int classIndex) {\n"
    c_function += "    switch(classIndex) {\n"

    for class_index, label in labels.items():
        c_function += f"        case {class_index}: return \"{label}\";\n"

    c_function += "        default: return \"Unknown\";\n"
    c_function += "    }\n"
    c_function += "}\n"

    # Save C function to file
    with open(output_file_path, 'w') as c_file:
        c_file.write(c_function)

    print("C function generated and saved to:", output_file_path)

# Example usage
generate_c_function('C:/colab/data/birds/labels.csv', 'C:/colab/data/birds/labels.h')
# Out:
# C function generated and saved to: C:/colab/data/birds/labels.h
